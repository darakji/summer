# %%
# !nvidia-smi
# Out:
# Tue Jul 22 18:35:19 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H200                    On  |   00000000:1B:00.0 Off |                   On |
# | N/A   28C    P0            112W /  700W |     221MiB / 143771MiB |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA H200                    On  |   00000000:43:00.0 Off |                   On |
# | N/A   29C    P0            109W /  700W |   12972MiB / 143771MiB |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA H200                    On  |   00000000:52:00.0 Off |                   On |
# | N/A   29C    P0             76W /  700W |      90MiB / 143771MiB |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA H200                    On  |   00000000:61:00.0 Off |                   On |
# | N/A   28C    P0             75W /  700W |      89MiB / 143771MiB |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA H200                    On  |   00000000:9D:00.0 Off |                   On |
# | N/A   25C    P0             76W /  700W |      89MiB / 143771MiB |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA H200                    On  |   00000000:C3:00.0 Off |                   On |
# | N/A   26C    P0             76W /  700W |      89MiB / 143771MiB |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    6   0   0  |             145MiB / 33024MiB    | 26      0 |  1   0    1    0    1 |
# |                  |                 2MiB / 65535MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0    6    0    3155525      C   ...niconda3/envs/mace_0.3.8/bin/python        124MiB |
# |    1    1    0    3152266      C   python                                      13010MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.5.1+cu121
# True

# %%
import torch
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))  # Try this only if device_count > 0
# Out:
# 1
# NVIDIA H200 MIG 1g.35gb

# %%
import os
import torch
import json
import pandas as pd
import numpy as np
from ase.io import read
from ase.db import connect
from chgnet.model.model import CHGNet
from chgnet.model.dynamics import CHGNetCalculator
from ase.calculators.calculator import CalculatorError
print("📥 Starting... Loading Excel and preparing to write DB/XYZ")

# === Paths ===
orig_excels = [
    "/home/phanim/harshitrawat/summer/md/mdinfo_chgnet_predictions_forces.xlsx",
    "/home/phanim/harshitrawat/summer/md/strain_perturb_chgnet_predictions_forces.xlsx"
]
t2_split = "/home/phanim/harshitrawat/summer/md/T2_chgnet_labeled.xlsx"
base_dir   = "/home/phanim/harshitrawat/summer/md"
db_path    = "mace_train_T2.db"

# === Load & filter ===
df_orig = pd.concat([pd.read_excel(x) for x in orig_excels], ignore_index=True)
t2_files = set(pd.read_excel(t2_split)["file"])
df = df_orig[df_orig["file"].isin(t2_files)].reset_index(drop=True)

print(f"📂 Total T2 entries: {len(df)}")

# === Prepare lists ===
good = []   # tuples of (fname, E, F, S)
bad  = []   # list of fnames needing CHGNet

for row in df.itertuples(index=False):
    fname = row.file
    try:
        E = float(row.energy_eV)
        F = json.loads(row.forces_per_atom_eV_per_A)
        S = json.loads(row.stress_tensor)
        # quick length check
        # we’ll verify atom count later
        good.append((fname, E, F, S))
    except Exception:
        bad.append(fname)

print(f"✅ Good JSON: {len(good)}, ⚠️ Bad JSON entries: {len(bad)}")

# === Helper ===
def resolve_cif(fname):
    sub = "mdcifs_strained_perturbed" if "perturbed" in fname else "mdcifs"
    return os.path.join(base_dir, sub, fname)

# === Open DB ===
n_ok = n_fail = n_recomputed = 0
with connect(db_path, append=False) as db:

    # 1) Write all good entries
    print("\n▶️ Writing all valid entries to DB…")
    for i, (fname, E, F, S) in enumerate(good, 1):
        path = resolve_cif(fname)
        if not os.path.exists(path):
            print(f"❌ [{i}/{len(good)}] Missing CIF: {fname}")
            n_fail += 1
            continue
        try:
            atoms = read(path)
            if len(F) != len(atoms):
                raise ValueError("Atom/force count mismatch")
            atoms.info["energy"]  = E
            atoms.info["stress"]  = S
            atoms.arrays["forces"] = F
            db.write(atoms)
            n_ok += 1
            print(f"✅ [{i}/{len(good)}] {fname}")
        except Exception as e:
            print(f"❌ [{i}/{len(good)}] {fname} — {e}")
            n_fail += 1

    # 2) Recompute bad entries on GPU
    if bad:
        print(f"\n▶️ Recomputing {len(bad)} bad entries on {device}…")
        # Explicit MIG workaround
        device = torch.device("cuda:0")
        
        # Load model manually on CPU
        model = CHGNet.load(use_device="cpu", verbose=True)
        
        # Force move to device
        model = model.to(device)
        
        # Build calculator manually
        calc = CHGNetCalculator(model=model, use_device=device)

        for j, fname in enumerate(bad, 1):
            path = resolve_cif(fname)
            if not os.path.exists(path):
                print(f"❌ [{j}/{len(bad)}] Missing CIF: {fname}")
                n_fail += 1
                continue
            try:
                atoms = read(path)
                atoms.calc = calc
                E = atoms.get_potential_energy()
                F = atoms.get_forces().tolist()
                S = atoms.get_stress(voigt=False).tolist()
                if len(F) != len(atoms):
                    raise ValueError("Atom/force count mismatch")
                atoms.info["energy"]  = float(E)
                atoms.info["stress"]  = S
                atoms.arrays["forces"] = F
                db.write(atoms)
                n_recomputed += 1
                print(f"🛠 [{j}/{len(bad)}] Recomputed {fname}")
            except CalculatorError as e:
                print(f"⚠️ [{j}/{len(bad)}] CHGNet failed: {fname} — {e}")
                n_fail += 1
            except Exception as e:
                print(f"❌ [{j}/{len(bad)}] {fname} — {e}")
                n_fail += 1

print(f"\n🎉 Done — OK: {n_ok}, Recomputed: {n_recomputed}, Failed: {n_fail}")
print(f"📦 DB written to: {db_path}")
# Out:
# 📥 Starting... Loading Excel and preparing to write DB/XYZ
# 📂 Total T2 entries: 3169
# ✅ Good JSON: 0, ⚠️ Bad JSON entries: 3169
#
# ▶️ Writing all valid entries to DB…
#
# ▶️ Recomputing 3169 bad entries on cuda:0…
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu
# /home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/chgnet/model/model.py:673: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(path, map_location=torch.device("cpu"))
# CHGNet will run on cuda:0
# 🛠 [1/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0000.cif
# 🛠 [2/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0001.cif
# 🛠 [3/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0002.cif
# 🛠 [4/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0003.cif
# 🛠 [5/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0004.cif
# 🛠 [6/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0005.cif
# 🛠 [7/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0007.cif
# 🛠 [8/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0009.cif
# 🛠 [9/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0010.cif
# 🛠 [10/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0011.cif
# 🛠 [11/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0013.cif
# 🛠 [12/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0016.cif
# 🛠 [13/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0020.cif
# 🛠 [14/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_
3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0095.cif
# 🛠 [491/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0102.cif
# 🛠 [492/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0105.cif
# 🛠 [493/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0113.cif
# 🛠 [494/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0115.cif
# 🛠 [495/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0117.cif
# 🛠 [496/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0119.cif
# 🛠 [497/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0120.cif
# 🛠 [498/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0126.cif
# 🛠 [499/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0127.cif
# 🛠 [500/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0128.cif
# 🛠 [501/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0131.cif
# 🛠 [502/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0133.cif
# 🛠 [503/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0134.cif
# 🛠 [504/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0136.cif
# 🛠 [505/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0138.cif
# 🛠 [506/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0140.cif
# 🛠 [507/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0142.cif
# 🛠 [508/3169] Recomputed cellrelaxed_LLZO_001_Zr_code93_sto__Li_111_slab_heavy_T450_0143.cif
# ...
# 🛠 [3028/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0110_strain-2_perturbed.cif
# 🛠 [3029/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0110_strain-3_perturbed.cif
# 🛠 [3030/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0142_strain+2_perturbed.cif
# 🛠 [3031/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0142_strain-3_perturbed.cif
# 🛠 [3032/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0149_strain+2_perturbed.cif
# 🛠 [3033/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0149_strain-2_perturbed.cif
# 🛠 [3034/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_100_slab_heavy_T450_0149_strain-3_perturbed.cif
# 🛠 [3035/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0014_strain-3_perturbed.cif
# 🛠 [3036/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0017_strain+2_perturbed.cif
# 🛠 [3037/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0017_strain-2_perturbed.cif
# 🛠 [3038/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0023_strain+2_perturbed.cif
# 🛠 [3039/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0023_strain+3_perturbed.cif
# 🛠 [3040/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0052_strain-2_perturbed.cif
# 🛠 [3041/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0074_strain+2_perturbed.cif
# 🛠 [3042/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0074_strain+3_perturbed.cif
# 🛠 [3043/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0074_strain-2_perturbed.cif
# 🛠 [3044/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0103_strain+2_perturbed.cif
# 🛠 [3045/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0103_strain+3_perturbed.cif
# 🛠 [3046/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0159_strain-3_perturbed.cif
# 🛠 [3047/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0183_strain+2_perturbed.cif
# 🛠 [3048/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T300_0183_strain+3_perturbed.cif
# 🛠 [3049/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0057_strain+2_perturbed.cif
# 🛠 [3050/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0057_strain-2_perturbed.cif
# 🛠 [3051/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0060_strain+3_perturbed.cif
# 🛠 [3052/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0090_strain-3_perturbed.cif
# 🛠 [3053/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0107_strain+3_perturbed.cif
# 🛠 [3054/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0120_strain+3_perturbed.cif
# 🛠 [3055/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0120_strain-2_perturbed.cif
# 🛠 [3056/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0120_strain-3_perturbed.cif
# 🛠 [3057/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0149_strain+3_perturbed.cif
# 🛠 [3058/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0149_strain-3_perturbed.cif
# 🛠 [3059/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0171_strain-3_perturbed.cif
# 🛠 [3060/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0200_strain+2_perturbed.cif
# 🛠 [3061/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0200_strain+3_perturbed.cif
# 🛠 [3062/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_110_slab_heavy_T450_0200_strain-2_perturbed.cif
# 🛠 [3063/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0037_strain+2_perturbed.cif
# 🛠 [3064/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0037_strain+3_perturbed.cif
# 🛠 [3065/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0038_strain-2_perturbed.cif
# 🛠 [3066/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0038_strain-3_perturbed.cif
# 🛠 [3067/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0058_strain+3_perturbed.cif
# 🛠 [3068/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0065_strain+3_perturbed.cif
# 🛠 [3069/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0065_strain-3_perturbed.cif
# 🛠 [3070/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0072_strain+3_perturbed.cif
# 🛠 [3071/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0081_strain+3_perturbed.cif
# 🛠 [3072/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0137_strain+3_perturbed.cif
# 🛠 [3073/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0137_strain-3_perturbed.cif
# 🛠 [3074/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0175_strain+2_perturbed.cif
# 🛠 [3075/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0175_strain+3_perturbed.cif
# 🛠 [3076/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0175_strain-2_perturbed.cif
# 🛠 [3077/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T300_0176_strain-2_perturbed.cif
# 🛠 [3078/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0014_strain+2_perturbed.cif
# 🛠 [3079/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0014_strain+3_perturbed.cif
# 🛠 [3080/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0014_strain-2_perturbed.cif
# 🛠 [3081/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0014_strain-3_perturbed.cif
# 🛠 [3082/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0115_strain+2_perturbed.cif
# 🛠 [3083/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0115_strain-2_perturbed.cif
# 🛠 [3084/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0115_strain-3_perturbed.cif
# 🛠 [3085/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0125_strain+3_perturbed.cif
# 🛠 [3086/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0150_strain+3_perturbed.cif
# 🛠 [3087/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0150_strain-3_perturbed.cif
# 🛠 [3088/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0197_strain+3_perturbed.cif
# 🛠 [3089/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0197_strain-2_perturbed.cif
# 🛠 [3090/3169] Recomputed cellrelaxed_LLZO_010_Li_order4_off__Li_111_slab_heavy_T450_0197_strain-3_perturbed.cif
# 🛠 [3091/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0024_strain-2_perturbed.cif
# 🛠 [3092/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0024_strain-3_perturbed.cif
# 🛠 [3093/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0051_strain-2_perturbed.cif
# 🛠 [3094/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0051_strain-3_perturbed.cif
# 🛠 [3095/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0087_strain-3_perturbed.cif
# 🛠 [3096/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0099_strain-3_perturbed.cif
# 🛠 [3097/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0169_strain-3_perturbed.cif
# 🛠 [3098/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0178_strain+2_perturbed.cif
# 🛠 [3099/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0178_strain+3_perturbed.cif
# 🛠 [3100/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0178_strain-3_perturbed.cif
# 🛠 [3101/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0192_strain+2_perturbed.cif
# 🛠 [3102/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T300_0192_strain+3_perturbed.cif
# 🛠 [3103/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T450_0037_strain+3_perturbed.cif
# 🛠 [3104/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T450_0120_strain+2_perturbed.cif
# 🛠 [3105/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T450_0120_strain+3_perturbed.cif
# 🛠 [3106/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T450_0120_strain-3_perturbed.cif
# 🛠 [3107/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T450_0172_strain+2_perturbed.cif
# 🛠 [3108/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_100_slab_heavy_T450_0200_strain-3_perturbed.cif
# 🛠 [3109/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0090_strain+3_perturbed.cif
# 🛠 [3110/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0136_strain+2_perturbed.cif
# 🛠 [3111/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0136_strain+3_perturbed.cif
# 🛠 [3112/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0136_strain-2_perturbed.cif
# 🛠 [3113/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0166_strain+3_perturbed.cif
# 🛠 [3114/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0166_strain-3_perturbed.cif
# 🛠 [3115/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0183_strain+2_perturbed.cif
# 🛠 [3116/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0183_strain+3_perturbed.cif
# 🛠 [3117/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0183_strain-2_perturbed.cif
# 🛠 [3118/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T300_0183_strain-3_perturbed.cif
# 🛠 [3119/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0006_strain+3_perturbed.cif
# 🛠 [3120/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0006_strain-3_perturbed.cif
# 🛠 [3121/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0030_strain+2_perturbed.cif
# 🛠 [3122/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0055_strain+2_perturbed.cif
# 🛠 [3123/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0055_strain-2_perturbed.cif
# 🛠 [3124/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0055_strain-3_perturbed.cif
# 🛠 [3125/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0079_strain+2_perturbed.cif
# 🛠 [3126/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0079_strain-3_perturbed.cif
# 🛠 [3127/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0090_strain+2_perturbed.cif
# 🛠 [3128/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0090_strain+3_perturbed.cif
# 🛠 [3129/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0090_strain-2_perturbed.cif
# 🛠 [3130/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0090_strain-3_perturbed.cif
# 🛠 [3131/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0096_strain+3_perturbed.cif
# 🛠 [3132/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0096_strain-2_perturbed.cif
# 🛠 [3133/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0096_strain-3_perturbed.cif
# 🛠 [3134/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0107_strain+2_perturbed.cif
# 🛠 [3135/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0107_strain+3_perturbed.cif
# 🛠 [3136/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0107_strain-2_perturbed.cif
# 🛠 [3137/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0107_strain-3_perturbed.cif
# 🛠 [3138/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0122_strain+3_perturbed.cif
# 🛠 [3139/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0122_strain-2_perturbed.cif
# 🛠 [3140/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0122_strain-3_perturbed.cif
# 🛠 [3141/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0152_strain-2_perturbed.cif
# 🛠 [3142/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0167_strain+2_perturbed.cif
# 🛠 [3143/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0167_strain-3_perturbed.cif
# 🛠 [3144/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0177_strain+2_perturbed.cif
# 🛠 [3145/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0177_strain+3_perturbed.cif
# 🛠 [3146/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0195_strain+3_perturbed.cif
# 🛠 [3147/3169] Recomputed cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0195_strain-3_perturbed.cif
# 🛠 [3148/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain+3_perturbed.cif
# 🛠 [3149/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain-2_perturbed.cif
# 🛠 [3150/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain-3_perturbed.cif
# 🛠 [3151/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain+3_perturbed.cif
# 🛠 [3152/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain-2_perturbed.cif
# 🛠 [3153/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain+2_perturbed.cif
# 🛠 [3154/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain-3_perturbed.cif
# 🛠 [3155/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain+2_perturbed.cif
# 🛠 [3156/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain+3_perturbed.cif
# 🛠 [3157/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain-3_perturbed.cif
# 🛠 [3158/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain+2_perturbed.cif
# 🛠 [3159/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain+3_perturbed.cif
# 🛠 [3160/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain-2_perturbed.cif
# 🛠 [3161/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain+3_perturbed.cif
# 🛠 [3162/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain-3_perturbed.cif
# 🛠 [3163/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain+2_perturbed.cif
# 🛠 [3164/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain-2_perturbed.cif
# 🛠 [3165/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain-3_perturbed.cif
# 🛠 [3166/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain+2_perturbed.cif
# 🛠 [3167/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain-2_perturbed.cif
# 🛠 [3168/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain+2_perturbed.cif
# 🛠 [3169/3169] Recomputed cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain-2_perturbed.cif
#
# 🎉 Done — OK: 0, Recomputed: 3168, Failed: 1
# 📦 DB written to: mace_train_T2.db

# %%
from chgnet.model.model import CHGNet

device = torch.device("cuda:0")

# Manually load model on CPU
model = CHGNet.load(use_device="cpu", verbose=True)

# Then manually move to your device (forces allocation)
model = model.to(device)

# Inject into calculator
calc = CHGNetCalculator(model=model, use_device=device)
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu
# CHGNet will run on cuda:0

# %%
import torch
print(torch.version.cuda)  # Should match CHGNet’s requirements (e.g., 12.1)
print(torch.cuda.is_available())  # True
print(torch.cuda.device_count())  # 1
print(torch.cuda.get_device_name(0))  # Should be your MIG slice
print(torch.cuda.current_device())  # Should be 0
# Out:
# 12.1
# True
# 1
# NVIDIA H200 MIG 1g.35gb
# 0

# %%
# !export CUDA_VISIBLE_DEVICES=0
