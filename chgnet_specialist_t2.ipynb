# %%
from ase.io import read
from chgnet.graph.converter import CrystalGraphConverter

# === Load .extxyz files ===
train_extxyz = "/home/phanim/harshitrawat/summer/final_work/T3_chgnet_labeled.extxyz"
# valid_extxyz = "/home/phanim/harshitrawat/summer/final_work/T2_chgnet_labeled.extxyz"

train_atoms = read(train_extxyz, index=":")
# valid_atoms = read(valid_extxyz, index=":")

print(f"✅ Loaded {len(train_atoms)} training structures")
# print(f"✅ Loaded {len(valid_atoms)} validation structures")

# === Initialize Converter ===
converter = CrystalGraphConverter(
    atom_graph_cutoff=6.0,
    bond_graph_cutoff=3.0,
    algorithm="fast",
    on_isolated_atoms="warn",
    verbose=True
)
# Out:
# ✅ Loaded 1612 training structures
# CrystalGraphConverter(algorithm='fast', atom_graph_cutoff=6.0, bond_graph_cutoff=3.0)

# %%
from joblib import Parallel, delayed
from pymatgen.io.ase import AseAtomsAdaptor
from chgnet.graph.converter import CrystalGraphConverter

# === Setup ===
ase_adaptor = AseAtomsAdaptor()
converter = CrystalGraphConverter(atom_graph_cutoff=6.0, bond_graph_cutoff=3.0,algorithm="fast",
    on_isolated_atoms="warn",
    verbose=True)

# === Function for one graph ===
def convert_atom(atom):
    structure = ase_adaptor.get_structure(atom)
    return converter(structure)
# Out:
# CrystalGraphConverter(algorithm='fast', atom_graph_cutoff=6.0, bond_graph_cutoff=3.0)

# %%
# === Parallel Execution ===
train_graphs = Parallel(n_jobs=32)(delayed(convert_atom)(atom) for atom in train_atoms)
# valid_graphs = Parallel(n_jobs=32)(delayed(convert_atom)(atom) for atom in valid_atoms)

# %%
import torch

torch.save(train_graphs, "t3_chgnet_graphs.pt")
# torch.save(valid_graphs, "t2_chgnet_graphs.pt")

print("✅ Saved graphs to disk.")
# Out:
# ✅ Saved graphs to disk.

# %%
import torch

# === Load validation graphs ===
valid_graphs = torch.load("/home/phanim/harshitrawat/summer/t2_chgnet_graphs.pt")
# Out:
# /tmp/ipykernel_3784347/3064465929.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   valid_graphs = torch.load("/home/phanim/harshitrawat/summer/t2_chgnet_graphs.pt")

# %%
from torch.utils.data import Dataset, DataLoader

class GraphDataset(Dataset):
    def __init__(self, graphs):
        self.graphs = graphs

    def __len__(self):
        return len(self.graphs)

    def __getitem__(self, idx):
        return self.graphs[idx]

# === Wrap datasets ===
train_dataset = GraphDataset(train_graphs)
valid_dataset = GraphDataset(valid_graphs)

# %%
# === Create loaders ===
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=False)

# %%
import torch
from chgnet.model.model import CHGNet

# === Force load on CPU first ===
device = torch.device("cuda:0")

# Load the model safely on CPU first
model = CHGNet.load(use_device="cpu", verbose=True)

# Then move manually to the MIG GPU
model = model.to(device)

# === Set to train mode ===
model.train()

# === Optional: Check model arch ===
print("✅ CHGNet loaded on", device)
# Out:
# /home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/chgnet/model/model.py:673: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(path, map_location=torch.device("cpu"))
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu
# ✅ CHGNet loaded on cuda:0

# %%
valid_extxyz = "/home/phanim/harshitrawat/summer/final_work/T2_chgnet_labeled.extxyz"
valid_atoms = read(valid_extxyz, index=":")

# %%
from chgnet.data.dataset import StructureData
import numpy as np
def atoms_to_structuredata(atoms_list):
    structures = []
    energies = []
    forces = []

    for atoms in atoms_list:
        structures.append(ase_adaptor.get_structure(atoms))

        energy = atoms.info.get("REF_energy", None)
        force = atoms.arrays.get("REF_forces", None)

        if energy is None or force is None:
            raise ValueError("Missing REF_energy or REF_forces")

        energies.append(energy)
        forces.append(np.array(force, dtype=np.float32))


    return StructureData(structures=structures, energies=energies, forces=forces)

train_data = atoms_to_structuredata(train_atoms)
valid_data = atoms_to_structuredata(valid_atoms)

print("✅ Created StructureData for training and validation")
# Out:
# StructureData imported 1,612 structures
# StructureData imported 705 structures
# ✅ Created StructureData for training and validation

# %%
import torch
from ase.io import write
import joblib

# === Atoms ===
write("t3_atoms.extxyz", train_atoms)

# === StructureData ===
joblib.dump(train_data, "t3_structure_data.pkl")

print("✅ Saved graphs, atoms, and structured datasets")
# Out:
# ✅ Saved graphs, atoms, and structured datasets

# %%
import os
from chgnet.trainer import Trainer
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
trainer = Trainer(
    model=model,
    targets="ef",           # energy + forces
    optimizer="Adam",
    criterion="MSE",
    learning_rate=1e-2,
    epochs=10,              # you can reduce to 10 for testing
    use_device=device
)

# %%
from chgnet.data.dataset import StructureData

# Merge two StructureData objects
full_data = StructureData(
    structures=train_data.structures + valid_data.structures,
    energies=train_data.energies + valid_data.energies,
    forces=train_data.forces + valid_data.forces,
)
# Out:
# StructureData imported 2,317 structures

# %%
from chgnet.data.dataset import get_train_val_test_loader
train_loader, val_loader, _ = get_train_val_test_loader(
    dataset=full_data,
    batch_size=4,
    train_ratio=len(train_data) / (len(train_data) + len(valid_data)),
    val_ratio=len(valid_data) / (len(train_data) + len(valid_data)),
    num_workers=4,
    pin_memory=True
)
trainer.train(train_loader, val_loader)
# Out:
# Begin Training: using cuda:0 device
# training targets: ef
# Epoch: [0][1/403] | Time (3.350)(2.652) | Loss 8147576.5000(8147576.5000) | MAE e 2846.950(2846.950)  f 0.000(0.000)
# Epoch: [0][100/403] | Time (0.884)(0.641) | Loss 13913.1172(4405001.0156) | MAE e 96.950(1741.461)  f 32.460(29.916)
# Epoch: [0][200/403] | Time (0.835)(0.596) | Loss 123764.5312(2232521.3921) | MAE e 264.744(967.267)  f 26.809(29.873)
# Epoch: [0][300/403] | Time (0.848)(0.609) | Loss 35156.8242(1502487.5164) | MAE e 108.872(700.156)  f 36.464(30.479)
# Epoch: [0][400/403] | Time (0.855)(0.619) | Loss 10215.9629(1134728.7083) | MAE e 78.252(560.131)  f 28.263(31.006)
# Val: [100/177] | Time (0.795) | Loss 22565.5059(57673.6318) | MAE e 106.556(192.912)  f 33.040(32.718)
# *   e_MAE (189.346) 	f_MAE (32.769)
# Epoch: [1][1/403] | Time (6.964)(6.669) | Loss 39943.0391(39943.0391) | MAE e 155.578(155.578)  f 30.701(30.701)
# Epoch: [1][100/403] | Time (0.968)(0.726) | Loss 65660.7266(30864.6952) | MAE e 209.546(144.756)  f 22.125(26.838)
# Epoch: [1][200/403] | Time (0.874)(0.640) | Loss 26706.5117(28678.8999) | MAE e 140.608(137.735)  f 23.129(26.893)
# Epoch: [1][300/403] | Time (0.873)(0.638) | Loss 48872.4336(29502.5505) | MAE e 200.055(140.418)  f 20.430(24.768)
# Epoch: [1][400/403] | Time (0.872)(0.636) | Loss 39982.3672(29494.6482) | MAE e 179.517(139.532)  f 16.189(23.314)
# Val: [100/177] | Time (0.856) | Loss 39584.0000(21913.9692) | MAE e 192.025(129.032)  f 15.091(14.858)
# *   e_MAE (125.925) 	f_MAE (14.831)
# Epoch: [2][1/403] | Time (2.363)(2.189) | Loss 25616.0996(25616.0996) | MAE e 138.453(138.453)  f 15.206(15.206)
# Epoch: [2][100/403] | Time (0.943)(0.688) | Loss 8087.2583(24258.4037) | MAE e 69.745(130.658)  f 15.786(14.669)
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fe4c4802020>>
# Traceback (most recent call last):
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Exception in thread Thread-9 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/torch/utils/data/_utils/pin_memory.py", line 59, in _pin_memory_loop
#     do_one_step()
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/torch/utils/data/_utils/pin_memory.py", line 35, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/multiprocessing/connection.py", line 502, in Client
#     c = SocketClient(address)
#   File "/home/phanim/harshitrawat/miniconda3/envs/mace_0.3.8/lib/python3.10/multiprocessing/connection.py", line 630, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 10
#       1 from chgnet.data.dataset import get_train_val_test_loader
#       2 train_loader, val_loader, _ = get_train_val_test_loader(
#       3     dataset=full_data,
#       4     batch_size=4,
#    (...)
#       8     pin_memory=True
#       9 )
# ---> 10 trainer.train(train_loader, val_loader)
#
# File ~/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/chgnet/trainer/trainer.py:243, in Trainer.train(self, train_loader, val_loader, test_loader, save_dir, save_test_result, train_composition_model)
#     239     param.requires_grad = train_composition_model
#     241 for epoch in range(self.starting_epoch, self.epochs):
#     242     # train
# --> 243     train_mae = self._train(train_loader, epoch)
#     244     if "e" in train_mae and train_mae["e"] != train_mae["e"]:
#     245         print("Exit due to NaN")
#
# File ~/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/chgnet/trainer/trainer.py:327, in Trainer._train(self, train_loader, current_epoch)
#     325 # compute gradient and do SGD step
#     326 self.optimizer.zero_grad()
# --> 327 combined_loss["loss"].backward()
#     328 self.optimizer.step()
#     330 # adjust learning rate every 1/10 of the epoch
#
# File ~/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/mace_0.3.8/lib/python3.10/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import os
from chgnet.trainer import Trainer
from chgnet.data.dataset import get_train_val_test_loader

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

trainer = Trainer(
    model=model,
    targets="ef",           # energy + forces
    optimizer="Adam",
    criterion="MSE",
    learning_rate=1e-3,
    epochs=10,              # you can reduce to 10 for testing
    use_device=device
)

train_loader, val_loader, _ = get_train_val_test_loader(
    dataset=full_data,
    batch_size=4,
    train_ratio=len(train_data) / (len(train_data) + len(valid_data)),
    val_ratio=len(valid_data) / (len(train_data) + len(valid_data)),
    num_workers=4,
    pin_memory=True
)
trainer.train(train_loader, val_loader)
# Out:
# Begin Training: using cuda:0 device
# training targets: ef
# Epoch: [0][1/403] | Time (7.494)(7.239) | Loss 28128.0000(28128.0000) | MAE e 137.827(137.827)  f 14.108(14.108)
# Epoch: [0][100/403] | Time (0.953)(0.717) | Loss 4919.1357(21626.8521) | MAE e 63.225(125.098)  f 13.551(13.773)
# Epoch: [0][200/403] | Time (0.880)(0.647) | Loss 26392.4531(21444.5587) | MAE e 144.800(124.561)  f 11.996(13.469)
# Epoch: [0][300/403] | Time (0.894)(0.660) | Loss 8416.9648(21028.4198) | MAE e 87.650(123.944)  f 12.484(12.979)
# Epoch: [0][400/403] | Time (0.880)(0.648) | Loss 21321.4492(20758.2915) | MAE e 138.106(123.531)  f 12.685(12.788)
# Val: [100/177] | Time (0.926) | Loss 14084.3691(19420.6850) | MAE e 95.519(118.418)  f 11.843(11.950)
# *   e_MAE (118.149) 	f_MAE (11.974)
# Epoch: [1][1/403] | Time (7.154)(6.851) | Loss 15058.1543(15058.1543) | MAE e 100.539(100.539)  f 12.546(12.546)
# Epoch: [1][100/403] | Time (0.881)(0.644) | Loss 17774.2871(20570.5069) | MAE e 119.146(121.645)  f 11.111(12.384)
# Epoch: [1][200/403] | Time (0.813)(0.585) | Loss 14189.5645(20409.0335) | MAE e 105.244(122.708)  f 11.093(11.973)
# Epoch: [1][300/403] | Time (0.846)(0.614) | Loss 20584.6543(20779.3948) | MAE e 134.833(123.509)  f 10.276(12.058)
# Epoch: [1][400/403] | Time (0.872)(0.639) | Loss 21946.3262(20586.9702) | MAE e 143.301(123.033)  f 11.931(12.130)
# Val: [100/177] | Time (0.867) | Loss 23332.8984(18437.9897) | MAE e 131.093(116.436)  f 13.071(11.977)
# *   e_MAE (117.863) 	f_MAE (12.029)
# Epoch: [2][1/403] | Time (2.521)(2.394) | Loss 36984.3828(36984.3828) | MAE e 191.148(191.148)  f 11.585(11.585)
# Epoch: [2][100/403] | Time (0.907)(0.674) | Loss 21932.8145(18560.6527) | MAE e 145.629(117.160)  f 10.360(11.271)
# Epoch: [2][200/403] | Time (0.875)(0.641) | Loss 17582.7383(19095.5108) | MAE e 103.575(118.239)  f 11.629(11.622)
# Epoch: [2][300/403] | Time (0.880)(0.648) | Loss 22978.8398(19809.8640) | MAE e 140.086(121.542)  f 12.602(11.917)
# Epoch: [2][400/403] | Time (0.873)(0.641) | Loss 31964.4492(19860.1355) | MAE e 171.850(122.004)  f 10.492(11.985)
# Val: [100/177] | Time (0.870) | Loss 18140.2324(18667.2249) | MAE e 117.677(117.575)  f 11.817(11.668)
# *   e_MAE (117.554) 	f_MAE (11.643)
# Epoch: [3][1/403] | Time (6.760)(6.579) | Loss 17081.7266(17081.7266) | MAE e 124.617(124.617)  f 12.593(12.593)
# Epoch: [3][100/403] | Time (0.864)(0.630) | Loss 25614.1719(19208.8714) | MAE e 121.940(119.143)  f 12.937(11.692)
# Epoch: [3][200/403] | Time (0.918)(0.682) | Loss 9640.4199(19443.8409) | MAE e 95.761(119.202)  f 11.544(12.363)
# Epoch: [3][300/403] | Time (0.886)(0.653) | Loss 22478.4277(19310.8115) | MAE e 143.297(118.861)  f 13.210(12.157)
# Epoch: [3][400/403] | Time (0.884)(0.651) | Loss 17952.6133(19792.5613) | MAE e 106.955(120.490)  f 11.374(12.127)
# Val: [100/177] | Time (0.829) | Loss 24551.7207(19915.1964) | MAE e 152.010(119.828)  f 12.397(11.890)
# *   e_MAE (119.097) 	f_MAE (11.938)
# Epoch: [4][1/403] | Time (2.277)(2.113) | Loss 8752.2295(8752.2295) | MAE e 69.427(69.427)  f 11.132(11.132)
# Epoch: [4][100/403] | Time (0.828)(0.597) | Loss 33540.9844(18804.6035) | MAE e 179.552(118.154)  f 11.679(11.778)
# Epoch: [4][200/403] | Time (0.833)(0.605) | Loss 21490.6191(18977.1338) | MAE e 130.946(118.323)  f 11.426(11.846)
# Epoch: [4][300/403] | Time (0.861)(0.632) | Loss 16272.1035(19335.8672) | MAE e 110.828(120.124)  f 11.598(11.986)
# Epoch: [4][400/403] | Time (0.845)(0.613) | Loss 29363.5840(19372.6265) | MAE e 167.951(120.291)  f 12.092(12.116)
# Val: [100/177] | Time (0.857) | Loss 27728.8340(18551.2071) | MAE e 136.595(116.077)  f 13.876(12.532)
# *   e_MAE (117.436) 	f_MAE (12.569)
# Epoch: [5][1/403] | Time (7.148)(6.906) | Loss 28327.1680(28327.1680) | MAE e 161.176(161.176)  f 13.723(13.723)
# Epoch: [5][100/403] | Time (0.856)(0.625) | Loss 13067.4951(18115.3596) | MAE e 99.412(117.068)  f 11.845(12.100)
# Epoch: [5][200/403] | Time (0.852)(0.621) | Loss 12492.5791(18919.2355) | MAE e 97.928(118.878)  f 10.319(12.114)
# Epoch: [5][300/403] | Time (0.870)(0.636) | Loss 17353.9688(19217.3197) | MAE e 118.366(119.996)  f 13.983(12.098)
# Epoch: [5][400/403] | Time (0.877)(0.644) | Loss 24293.3750(19458.2496) | MAE e 127.883(120.422)  f 13.526(12.199)
# Val: [100/177] | Time (0.866) | Loss 23608.2090(19353.9408) | MAE e 151.028(118.568)  f 11.436(12.660)
# *   e_MAE (118.662) 	f_MAE (12.695)
# Epoch: [6][1/403] | Time (7.104)(6.833) | Loss 14036.4355(14036.4355) | MAE e 82.650(82.650)  f 11.623(11.623)
# Epoch: [6][100/403] | Time (0.907)(0.675) | Loss 12755.9092(18833.0145) | MAE e 96.559(118.450)  f 12.594(12.803)
# Epoch: [6][200/403] | Time (0.850)(0.619) | Loss 22200.7051(19251.7285) | MAE e 144.647(119.377)  f 13.042(12.874)
# Epoch: [6][300/403] | Time (0.859)(0.628) | Loss 13379.4863(19236.6273) | MAE e 95.584(119.361)  f 12.018(12.850)
# Epoch: [6][400/403] | Time (0.877)(0.644) | Loss 31884.1152(19099.5689) | MAE e 175.900(119.192)  f 12.764(12.881)
# Val: [100/177] | Time (0.863) | Loss 26478.2793(17929.3214) | MAE e 158.708(114.131)  f 11.967(12.705)
# *   e_MAE (116.298) 	f_MAE (12.729)
# Epoch: [7][1/403] | Time (2.947)(2.669) | Loss 13438.8916(13438.8916) | MAE e 90.879(90.879)  f 13.623(13.623)
# Epoch: [7][100/403] | Time (0.888)(0.652) | Loss 14295.4092(19032.2712) | MAE e 97.328(118.520)  f 11.670(12.805)
# Epoch: [7][200/403] | Time (0.879)(0.644) | Loss 10546.5566(19032.2181) | MAE e 74.052(118.683)  f 12.746(12.864)
# Epoch: [7][300/403] | Time (0.877)(0.642) | Loss 42187.9414(18847.2624) | MAE e 198.011(118.621)  f 14.759(12.933)
# Epoch: [7][400/403] | Time (0.852)(0.620) | Loss 6597.3945(18668.8099) | MAE e 66.294(118.200)  f 12.799(12.911)
# Val: [100/177] | Time (0.969) | Loss 11405.0791(18378.8099) | MAE e 97.201(116.153)  f 14.772(13.078)
# *   e_MAE (116.024) 	f_MAE (12.963)
# Epoch: [8][1/403] | Time (6.508)(6.213) | Loss 25871.1855(25871.1855) | MAE e 133.219(133.219)  f 14.082(14.082)
# Epoch: [8][100/403] | Time (0.902)(0.668) | Loss 31372.8711(18804.3538) | MAE e 168.003(118.015)  f 13.695(12.864)
# Epoch: [8][200/403] | Time (0.894)(0.660) | Loss 11803.3691(18679.6014) | MAE e 94.806(118.558)  f 14.500(12.860)
# Epoch: [8][300/403] | Time (0.862)(0.631) | Loss 31861.2871(18796.8980) | MAE e 167.921(119.151)  f 14.331(12.900)
# Epoch: [8][400/403] | Time (0.869)(0.636) | Loss 9005.3223(18532.0891) | MAE e 83.698(118.125)  f 11.679(12.912)
# Val: [100/177] | Time (0.871) | Loss 11711.3711(18282.9832) | MAE e 103.175(115.744)  f 11.537(12.931)
# *   e_MAE (115.842) 	f_MAE (13.049)
# Epoch: [9][1/403] | Time (2.414)(2.228) | Loss 26657.5801(26657.5801) | MAE e 160.292(160.292)  f 12.056(12.056)
# Epoch: [9][100/403] | Time (0.946)(0.707) | Loss 17955.5195(17588.2705) | MAE e 115.649(114.340)  f 13.081(13.069)
# Epoch: [9][200/403] | Time (0.902)(0.667) | Loss 17166.7363(17918.9828) | MAE e 112.064(116.360)  f 12.728(13.029)
# Epoch: [9][300/403] | Time (0.905)(0.672) | Loss 47974.4180(18578.8025) | MAE e 214.784(118.837)  f 13.521(13.079)
# Epoch: [9][400/403] | Time (0.916)(0.683) | Loss 9903.5137(18444.5348) | MAE e 79.958(117.936)  f 13.985(13.084)
# Val: [100/177] | Time (0.874) | Loss 11815.3779(18315.8774) | MAE e 103.347(116.316)  f 12.356(13.159)
# *   e_MAE (115.996) 	f_MAE (13.133)

# %%
import torch
torch.cuda.empty_cache()

# %%
import os
import json
from ase.io import read
from chgnet.model.model import CHGNet
from chgnet.model.dynamics import CHGNetCalculator
import torch

# === Setup ===
folders = {
    "/home/phanim/harshitrawat/summer/md/mdcifs": "/home/phanim/harshitrawat/summer/final_work/mdinfo_chgnetT2_predictions_forces.json",
    "/home/phanim/harshitrawat/summer/md/mdcifs_strained_perturbed": "/home/phanim/harshitrawat/summer/final_work/strain_perturb_chgnetT2_predictions_forces.json"
}

device = torch.device("cuda:0")  # Adjust to MIG slice if needed

# === Load CHGNet ===
model = CHGNet.from_file("/home/phanim/harshitrawat/summer/07-29-2025/bestE_epoch8_e115842_f13049_sNA_mNA.pth.tar")
model = model.to(device)
calc = CHGNetCalculator(model=model, use_device=device)
print("✅ CHGNet model loaded")

def extract_info_from_cif(cif_path):
    try:
        atoms = read(cif_path)
        atoms.calc = calc

        energy = atoms.get_potential_energy()
        forces = atoms.get_forces()
        stress = atoms.get_stress(voigt=False).tolist()

        if forces.shape[0] != len(atoms):
            raise ValueError(f"Force shape mismatch: {forces.shape} vs {len(atoms)}")

        return {
            "file": os.path.basename(cif_path),
            "energy_eV": energy,
            "forces_per_atom_eV_per_A": forces.tolist(),
            "stress_tensor": stress,
            "magmom_total": atoms.get_magnetic_moment() if "magmom" in atoms.arrays else None
        }
    except Exception as e:
        return {
            "file": os.path.basename(cif_path),
            "error": str(e)
        }

# === Label and Save ===
for folder, out_json in folders.items():
    print(f"\n📂 Labeling: {folder}")
    results = []
    cif_files = sorted([f for f in os.listdir(folder) if f.endswith(".cif")])

    for i, fname in enumerate(cif_files):
        full_path = os.path.join(folder, fname)
        result = extract_info_from_cif(full_path)
        results.append(result)
        if "error" in result:
            print(f"❌ {i+1}/{len(cif_files)} — {fname} — {result['error']}")
        else:
            print(f"✅ {i+1}/{len(cif_files)} — {fname}")

    os.makedirs(os.path.dirname(out_json), exist_ok=True)
    with open(out_json, "w") as f:
        json.dump(results, f, indent=2)

    print(f"🧾 Saved {len(results)} entries to: {out_json}")
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda:0
# ✅ CHGNet model loaded
#
# 📂 Labeling: /home/phanim/harshitrawat/summer/md/mdcifs
# ✅ 1/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0000.cif
# ✅ 2/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0001.cif
# ✅ 3/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0002.cif
# ✅ 4/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0003.cif
# ✅ 5/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0004.cif
# ✅ 6/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0005.cif
# ✅ 7/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0006.cif
# ✅ 8/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0007.cif
# ✅ 9/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0008.cif
# ✅ 10/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0009.cif
# ✅ 11/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0010.cif
# ✅ 12/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0011.cif
# ✅ 13/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0012.cif
# ✅ 14/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0013.cif
# ✅ 15/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0014.cif
# ✅ 16/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0015.cif
# ✅ 17/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0016.cif
# ✅ 18/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0017.cif
# ✅ 19/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0018.cif
# ✅ 20/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0019.cif
# ✅ 21/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0020.cif
# ✅ 22/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0021.cif
# ✅ 23/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0022.cif
# ✅ 24/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0023.cif
# ✅ 25/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0024.cif
# ✅ 26/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0025.cif
# ✅ 27/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0026.cif
# ✅ 28/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0027.cif
# ✅ 29/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0028.cif
# ✅ 30/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0029.cif
# ✅ 31/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0030.cif
# ✅ 32/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0031.cif
# ✅ 33/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0032.cif
# ✅ 34/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0033.cif
# ✅ 35/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0034.cif
# ✅ 36/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0035.cif
# ✅ 37/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0036.cif
# ✅ 38/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0037.cif
# ✅ 39/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0038.cif
# ✅ 40/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0039.cif
# ✅ 41/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0040.cif
# ✅ 42/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0041.cif
# ✅ 43/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0042.cif
# ✅ 44/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0043.cif
# ✅ 45/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0044.cif
# ✅ 46/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0045.cif
# ✅ 47/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0046.cif
# ✅ 48/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0047.cif
# ✅ 49/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0048.cif
# ✅ 50/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0049.cif
# ✅ 51/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0050.cif
# ✅ 52/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0051.cif
# ✅ 53/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0052.cif
# ✅ 54/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0053.cif
# ✅ 55/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0054.cif
# ✅ 56/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0055.cif
# ✅ 57/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0056.cif
# ✅ 58/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0057.cif
# ✅ 59/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0058.cif
# ✅ 60/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0059.cif
# ✅ 61/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0060.cif
# ✅ 62/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0061.cif
# ✅ 63/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0062.cif
# ✅ 64/6030 — cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_
1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0093_strain-2_perturbed.cif
# ✅ 976/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0093_strain-3_perturbed.cif
# ✅ 977/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain+2_perturbed.cif
# ✅ 978/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain+3_perturbed.cif
# ✅ 979/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain-2_perturbed.cif
# ✅ 980/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain-3_perturbed.cif
# ✅ 981/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain+2_perturbed.cif
# ✅ 982/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain+3_perturbed.cif
# ✅ 983/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain-2_perturbed.cif
# ✅ 984/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain-3_perturbed.cif
# ✅ 985/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain+2_perturbed.cif
# ✅ 986/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain+3_perturbed.cif
# ✅ 987/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain-2_perturbed.cif
# ✅ 988/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain-3_perturbed.cif
# ✅ 989/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain+2_perturbed.cif
# ✅ 990/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain+3_perturbed.cif
# ✅ 991/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain-2_perturbed.cif
# ✅ 992/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain-3_perturbed.cif
# ✅ 993/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain+2_perturbed.cif
# ✅ 994/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain+3_perturbed.cif
# ✅ 995/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain-2_perturbed.cif
# ✅ 996/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain-3_perturbed.cif
# ✅ 997/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain+2_perturbed.cif
# ✅ 998/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain+3_perturbed.cif
# ✅ 999/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain-2_perturbed.cif
# ✅ 1000/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain-3_perturbed.cif
# ✅ 1001/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain+2_perturbed.cif
# ✅ 1002/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain+3_perturbed.cif
# ✅ 1003/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain-2_perturbed.cif
# ✅ 1004/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain-3_perturbed.cif
# ✅ 1005/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain+2_perturbed.cif
# ✅ 1006/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain+3_perturbed.cif
# ✅ 1007/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain-2_perturbed.cif
# ✅ 1008/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain-3_perturbed.cif
# ✅ 1009/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain+2_perturbed.cif
# ✅ 1010/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain+3_perturbed.cif
# ✅ 1011/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain-2_perturbed.cif
# ✅ 1012/1012 — cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain-3_perturbed.cif
# 🧾 Saved 1012 entries to: /home/phanim/harshitrawat/summer/final_work/strain_perturb_chgnetT2_predictions_forces.json

# %%
import os
import json
import numpy as np
import pandas as pd

# === Input Paths ===
ref_paths = [
    "/home/phanim/harshitrawat/summer/final_work/mdinfo_chgnet_predictions_forces.json",
    "/home/phanim/harshitrawat/summer/final_work/strain_perturb_chgnet_predictions_forces.json"
]
t2_paths = [
    "/home/phanim/harshitrawat/summer/final_work/mdinfo_chgnetT2_predictions_forces.json",
    "/home/phanim/harshitrawat/summer/final_work/strain_perturb_chgnetT2_predictions_forces.json"
]

# === Load and combine
def load(pathlist):
    data = []
    for path in pathlist:
        with open(path) as f:
            data += json.load(f)
    return {d["file"]: d for d in data if "error" not in d}

ref_data = load(ref_paths)
t2_data = load(t2_paths)

# === Compare logic
results = []
for file, ref in ref_data.items():
    if file not in t2_data:
        print(f"[WARN] Missing in CHGNet_T2: {file}")
        continue
   

    pred = t2_data[file]

    f_ref = np.array(ref["forces_per_atom_eV_per_A"])
    f_pred = np.array(pred["forces_per_atom_eV_per_A"])

    if f_ref.shape != f_pred.shape:
        print(f"[SKIP] Shape mismatch in {file}: {f_ref.shape} vs {f_pred.shape}")
        continue

    num_atoms = f_ref.shape[0]
    delta_F = f_pred - f_ref

    force_mae = np.mean(np.abs(delta_F))
    force_rmse = np.sqrt(np.mean(delta_F**2))
    force_max = np.max(np.abs(delta_F))

    e_ref = ref["energy_eV"] / num_atoms
    e_pred = pred["energy_eV"] / num_atoms
    delta_E = e_pred - e_ref
    print(f"{file} | e_ref = {e_ref:.6f} | e_pred = {e_pred:.6f} | ΔE = {delta_E:.6f}")
    print(f"   f_ref[0] = {f_ref[0]} | f_pred[0] = {f_pred[0]}")
    results.append({
        "file": file,
        "num_atoms": num_atoms,
        "energy_ref_eV_per_atom": e_ref,
        "energy_t2_eV_per_atom": e_pred,
        "delta_E_eV_per_atom": delta_E,
        "force_mae_eV_per_A": force_mae,
        "force_rmse_eV_per_A": force_rmse,
        "force_max_abs_eV_per_A": force_max
    })

# === Save
out_json = "chgnetT2_vs_universal_comparison.json"
out_excel = "chgnetT2_vs_universal_comparison.xlsx"

with open(out_json, "w") as f:
    json.dump(results, f, indent=2)

df = pd.DataFrame(results)
df.to_excel(out_excel, index=False)

print(f"\n✅ Saved JSON: {out_json}")
print(f"📊 Saved Excel: {out_excel}")

# === Stats
print("\n📊 Global Stats (eV, eV/Å):")
print(f"Energy MAE (per atom): {np.mean(np.abs(df['delta_E_eV_per_atom'])):.5f} eV")
print(f"Energy RMSE (per atom): {np.sqrt(np.mean(df['delta_E_eV_per_atom']**2)):.5f} eV")
print(f"Force MAE: {df['force_mae_eV_per_A'].mean():.5f} eV/Å")
print(f"Force RMSE: {df['force_rmse_eV_per_A'].mean():.5f} eV/Å")
print(f"Max Force Abs Error: {df['force_max_abs_eV_per_A'].max():.5f} eV/Å")
# Out:
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0000.cif | e_ref = -4.302460 | e_pred = -2584.395996 | ΔE = -2580.093536
#    f_ref[0] = [ 0.00165386  0.00659467 -0.00422581] | f_pred[0] = [15.70427322 60.51914597 90.02623749]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0001.cif | e_ref = -4.300037 | e_pred = -2584.396484 | ΔE = -2580.096447
#    f_ref[0] = [ 0.34420848  0.10195164 -0.08806539] | f_pred[0] = [13.99886322 65.90104675 87.10457611]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0002.cif | e_ref = -4.293908 | e_pred = -2584.398193 | ΔE = -2580.104286
#    f_ref[0] = [ 0.57426876  0.23519236 -0.12259344] | f_pred[0] = [ 18.17464447  80.14640045 100.38053894]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0003.cif | e_ref = -4.286927 | e_pred = -2584.395020 | ΔE = -2580.108093
#    f_ref[0] = [ 0.63648605  0.28764218 -0.13436666] | f_pred[0] = [ 28.71493721  86.31601715 113.29589844]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0004.cif | e_ref = -4.281800 | e_pred = -2584.385986 | ΔE = -2580.104187
#    f_ref[0] = [ 0.57142776  0.35768509 -0.09218767] | f_pred[0] = [ 32.43726349  88.08097076 122.21915436]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0005.cif | e_ref = -4.279395 | e_pred = -2584.390137 | ΔE = -2580.110742
#    f_ref[0] = [ 0.36411077  0.36113095 -0.05124473] | f_pred[0] = [ 39.60577011  88.93286133 123.27578735]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0006.cif | e_ref = -4.278961 | e_pred = -2584.402344 | ΔE = -2580.123383
#    f_ref[0] = [ 0.02423784  0.28128088 -0.00065508] | f_pred[0] = [ 28.29919243  84.46382904 113.16022491]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0007.cif | e_ref = -4.279407 | e_pred = -2584.415283 | ΔE = -2580.135876
#    f_ref[0] = [-0.27980214  0.18742311  0.05473832] | f_pred[0] = [ 36.08902359  74.0534668  111.740242  ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0008.cif | e_ref = -4.280173 | e_pred = -2584.413574 | ΔE = -2580.133401
#    f_ref[0] = [-0.51513958  0.05436562  0.08452551] | f_pred[0] = [ 34.61354446  62.878685   104.950737  ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0009.cif | e_ref = -4.281069 | e_pred = -2584.410400 | ΔE = -2580.129331
#    f_ref[0] = [-0.61397338 -0.02910443  0.11388266] | f_pred[0] = [ 36.46826935  59.09690857 107.01918793]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0010.cif | e_ref = -4.282075 | e_pred = -2584.401367 | ΔE = -2580.119292
#    f_ref[0] = [-0.5940944  -0.08118606  0.11745279] | f_pred[0] = [ 26.97550583  56.01826477 100.4664917 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0011.cif | e_ref = -4.282944 | e_pred = -2584.380127 | ΔE = -2580.097183
#    f_ref[0] = [-0.47455293 -0.0988865   0.1268732 ] | f_pred[0] = [14.45931244 55.39335632 93.84337616]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0012.cif | e_ref = -4.283344 | e_pred = -2584.350098 | ΔE = -2580.066754
#    f_ref[0] = [-0.24846049 -0.05620398  0.14187221] | f_pred[0] = [ 5.22930622 61.21978378 91.65144348]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0013.cif | e_ref = -4.283120 | e_pred = -2584.316162 | ΔE = -2580.033042
#    f_ref[0] = [-0.00949526  0.01306466  0.15287897] | f_pred[0] = [12.04798317 80.27601624 98.20453644]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0014.cif | e_ref = -4.282375 | e_pred = -2584.289795 | ΔE = -2580.007420
#    f_ref[0] = [0.22144419 0.06029775 0.14203438] | f_pred[0] = [ 8.20858192 94.31476593 94.78432465]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0015.cif | e_ref = -4.281509 | e_pred = -2584.268311 | ΔE = -2579.986802
#    f_ref[0] = [0.38076049 0.06603236 0.10072212] | f_pred[0] = [10.60015488 97.66023254 97.17095184]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0016.cif | e_ref = -4.280902 | e_pred = -2584.254150 | ΔE = -2579.973248
#    f_ref[0] = [0.4211311  0.02509409 0.01704816] | f_pred[0] = [  0.32070971 107.88401794  96.67156982]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0017.cif | e_ref = -4.280622 | e_pred = -2584.242920 | ΔE = -2579.962297
#    f_ref[0] = [ 0.40060276 -0.0304487  -0.05372101] | f_pred[0] = [-3.31350565e-02  1.04753281e+02  9.15366669e+01]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0018.cif | e_ref = -4.280497 | e_pred = -2584.224854 | ΔE = -2579.944356
#    f_ref[0] = [ 0.34744722 -0.08756745 -0.12192231] | f_pred[0] = [ -0.22602963 101.36739349  85.7612915 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0019.cif | e_ref = -4.280593 | e_pred = -2584.196289 | ΔE = -2579.915696
#    f_ref[0] = [ 0.26586503 -0.1429745  -0.1596981 ] | f_pred[0] = [-0.56141543 96.06712341 78.27049255]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0020.cif | e_ref = -4.280906 | e_pred = -2584.161133 | ΔE = -2579.880227
#    f_ref[0] = [ 0.17635335 -0.15276568 -0.13709141] | f_pred[0] = [-1.65450382 84.42022705 72.13828278]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0021.cif | e_ref = -4.281116 | e_pred = -2584.133545 | ΔE = -2579.852429
#    f_ref[0] = [ 0.08309388 -0.18084015 -0.0651599 ] | f_pred[0] = [ 0.19858408 67.74520111 72.98964691]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0022.cif | e_ref = -4.281053 | e_pred = -2584.113770 | ΔE = -2579.832717
#    f_ref[0] = [-0.01771659 -0.18931524  0.0039867 ] | f_pred[0] = [ 5.51039886 55.09206009 74.9801712 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0023.cif | e_ref = -4.280810 | e_pred = -2584.102051 | ΔE = -2579.821240
#    f_ref[0] = [-0.0621507  -0.16514537  0.07439747] | f_pred[0] = [12.16823673 43.03833008 78.05110168]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0024.cif | e_ref = -4.280603 | e_pred = -2584.101807 | ΔE = -2579.821203
#    f_ref[0] = [-0.03943197 -0.12753956  0.10455385] | f_pred[0] = [ 7.21657705 33.20593643 81.64149475]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0025.cif | e_ref = -4.280509 | e_pred = -2584.127686 | ΔE = -2579.847176
#    f_ref[0] = [-0.02120178 -0.08619621  0.11549953] | f_pred[0] = [ 6.57567692 42.44781876 90.53817749]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0026.cif | e_ref = -4.280642 | e_pred = -2584.160156 | ΔE = -2579.879515
#    f_ref[0] = [-0.00501087 -0.04605055  0.09698328] | f_pred[0] = [ 12.60420704  54.9121666  100.41292572]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0027.cif | e_ref = -4.280898 | e_pred = -2584.185791 | ΔE = -2579.904893
#    f_ref[0] = [-0.01643251 -0.02023317  0.03075613] | f_pred[0] = [ 23.94231606  65.32698059 108.98899841]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0028.cif | e_ref = -4.281224 | e_pred = -2584.209229 | ΔE = -2579.928005
#    f_ref[0] = [-0.00846515  0.02215503 -0.05057454] | f_pred[0] = [ 27.79747581  83.13123322 118.27972412]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0029.cif | e_ref = -4.281575 | e_pred = -2584.220947 | ΔE = -2579.939373
#    f_ref[0] = [-0.01554211  0.07642545 -0.12536807] | f_pred[0] = [ 32.54956436  89.35897064 125.0652771 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0030.cif | e_ref = -4.281964 | e_pred = -2584.222656 | ΔE = -2579.940692
#    f_ref[0] = [-0.05195569  0.11680777 -0.17140579] | f_pred[0] = [ 27.25346947  96.89459991 129.92456055]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0031.cif | e_ref = -4.282241 | e_pred = -2584.214844 | ΔE = -2579.932602
#    f_ref[0] = [-0.04985369  0.13005307 -0.17142512] | f_pred[0] = [ 30.39190292  93.2317276  131.13824463]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0032.cif | e_ref = -4.282129 | e_pred = -2584.194580 | ΔE = -2579.912451
#    f_ref[0] = [-0.02782725  0.16368043 -0.11341304] | f_pred[0] = [ 29.07061386  88.38446808 129.3177948 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0033.cif | e_ref = -4.281459 | e_pred = -2584.186768 | ΔE = -2579.905309
#    f_ref[0] = [ 0.02103062  0.18791871 -0.04260861] | f_pred[0] = [ 26.12001419  86.95777893 127.71700287]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0034.cif | e_ref = -4.280518 | e_pred = -2584.198975 | ΔE = -2579.918457
#    f_ref[0] = [ 0.06526345  0.16573271 -0.00790305] | f_pred[0] = [ 25.10773277  78.47420502 120.07495117]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0035.cif | e_ref = -4.279723 | e_pred = -2584.220459 | ΔE = -2579.940736
#    f_ref[0] = [0.10268418 0.1093794  0.03990295] | f_pred[0] = [ 29.93253708  69.88652802 115.93147278]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0036.cif | e_ref = -4.279419 | e_pred = -2584.268311 | ΔE = -2579.988891
#    f_ref[0] = [0.12737602 0.04182956 0.04723437] | f_pred[0] = [ 36.68531799  59.67720795 111.9678421 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0037.cif | e_ref = -4.279568 | e_pred = -2584.332275 | ΔE = -2580.052708
#    f_ref[0] = [ 0.09068725 -0.01539877  0.0323449 ] | f_pred[0] = [ 44.48479843  45.10204697 112.48886108]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0038.cif | e_ref = -4.279845 | e_pred = -2584.395264 | ΔE = -2580.115418
#    f_ref[0] = [ 0.0042082  -0.08237416 -0.02830897] | f_pred[0] = [ 38.62937164  38.56759262 106.86016846]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0039.cif | e_ref = -4.279933 | e_pred = -2584.453125 | ΔE = -2580.173192
#    f_ref[0] = [-0.0991973  -0.14889404 -0.07609362] | f_pred[0] = [ 32.44032288  41.68121338 103.80789948]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0040.cif | e_ref = -4.279837 | e_pred = -2584.490479 | ΔE = -2580.210641
#    f_ref[0] = [-0.1894832  -0.18971726 -0.07476773] | f_pred[0] = [ 39.15892792  40.68616486 103.6595459 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0041.cif | e_ref = -4.279743 | e_pred = -2584.508789 | ΔE = -2580.229046
#    f_ref[0] = [-0.21941966 -0.21271592 -0.02103351] | f_pred[0] = [38.52583313 44.1003952  98.16080475]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0042.cif | e_ref = -4.279716 | e_pred = -2584.503906 | ΔE = -2580.224190
#    f_ref[0] = [-0.17174628 -0.19677374  0.07070673] | f_pred[0] = [33.83918762 47.55976486 96.21459961]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0043.cif | e_ref = -4.279713 | e_pred = -2584.474854 | ΔE = -2580.195140
#    f_ref[0] = [-0.04489525 -0.1527148   0.19551519] | f_pred[0] = [25.47795677 44.10977554 93.51345825]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0044.cif | e_ref = -4.279710 | e_pred = -2584.434326 | ΔE = -2580.154616
#    f_ref[0] = [ 0.11678763 -0.08444367  0.29783088] | f_pred[0] = [ 29.70561028  60.85227966 100.84607697]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0045.cif | e_ref = -4.279809 | e_pred = -2584.384521 | ΔE = -2580.104712
#    f_ref[0] = [ 0.22606139 -0.01061733  0.37435958] | f_pred[0] = [27.66585541 67.38204193 97.54121399]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0046.cif | e_ref = -4.280077 | e_pred = -2584.324951 | ΔE = -2580.044874
#    f_ref[0] = [0.25856873 0.03117714 0.39628235] | f_pred[0] = [25.67527962 83.13362122 97.94776917]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0047.cif | e_ref = -4.280358 | e_pred = -2584.259033 | ΔE = -2579.978675
#    f_ref[0] = [0.23013596 0.08241806 0.3397541 ] | f_pred[0] = [ 33.77471161  87.97557068 101.2755661 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0048.cif | e_ref = -4.280492 | e_pred = -2584.180420 | ΔE = -2579.899928
#    f_ref[0] = [0.14909682 0.11081884 0.22399867] | f_pred[0] = [32.50579453 87.62174225 97.63577271]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0049.cif | e_ref = -4.280425 | e_pred = -2584.090820 | ΔE = -2579.810395
#    f_ref[0] = [0.00411339 0.12378673 0.06933097] | f_pred[0] = [32.35425186 79.82810211 92.63033295]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0050.cif | e_ref = -4.280180 | e_pred = -2584.006592 | ΔE = -2579.726412
#    f_ref[0] = [-0.15131858  0.09481907 -0.11488599] | f_pred[0] = [ 35.87257004  73.61104584 102.0897522 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0051.cif | e_ref = -4.279864 | e_pred = -2583.940918 | ΔE = -2579.661054
#    f_ref[0] = [-0.28893459  0.04933059 -0.28136438] | f_pred[0] = [ 41.11068344  56.87717819 102.65670776]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0052.cif | e_ref = -4.279509 | e_pred = -2583.881104 | ΔE = -2579.601595
#    f_ref[0] = [-0.36860082  0.04777977 -0.37130541] | f_pred[0] = [42.41735458 45.55415344 98.62541962]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0053.cif | e_ref = -4.279162 | e_pred = -2583.831299 | ΔE = -2579.552136
#    f_ref[0] = [-0.369407    0.03588119 -0.38882875] | f_pred[0] = [45.75685883 49.07081985 99.24514771]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0054.cif | e_ref = -4.278898 | e_pred = -2583.788818 | ΔE = -2579.509921
#    f_ref[0] = [-0.31120217  0.06675462 -0.34925923] | f_pred[0] = [ 48.9393959   58.44908905 107.76115417]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0055.cif | e_ref = -4.278724 | e_pred = -2583.762695 | ΔE = -2579.483971
#    f_ref[0] = [-0.1863279   0.10531163 -0.2570388 ] | f_pred[0] = [ 47.44278717  70.50119781 103.66191864]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0056.cif | e_ref = -4.278534 | e_pred = -2583.738281 | ΔE = -2579.459747
#    f_ref[0] = [-0.01193243  0.16641808 -0.09482764] | f_pred[0] = [49.73734665 65.77742767 97.80995178]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0057.cif | e_ref = -4.278426 | e_pred = -2583.717529 | ΔE = -2579.439104
#    f_ref[0] = [0.11821373 0.15955015 0.03720187] | f_pred[0] = [46.83098984 70.07858276 95.04612732]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0058.cif | e_ref = -4.278599 | e_pred = -2583.695801 | ΔE = -2579.417202
#    f_ref[0] = [0.18377382 0.09238374 0.13682701] | f_pred[0] = [45.90322113 71.23885345 93.82146454]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0059.cif | e_ref = -4.278909 | e_pred = -2583.664795 | ΔE = -2579.385886
#    f_ref[0] = [0.18165569 0.01526231 0.18032357] | f_pred[0] = [38.73009491 76.27364349 95.66236877]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0060.cif | e_ref = -4.279042 | e_pred = -2583.622314 | ΔE = -2579.343273
#    f_ref[0] = [ 0.16034383 -0.03645515  0.19863251] | f_pred[0] = [26.49059296 74.71509552 88.66159058]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0061.cif | e_ref = -4.278936 | e_pred = -2583.575439 | ΔE = -2579.296504
#    f_ref[0] = [ 0.12877865 -0.07281925  0.20298038] | f_pred[0] = [17.21612167 70.26100922 87.91223145]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0062.cif | e_ref = -4.278796 | e_pred = -2583.514648 | ΔE = -2579.235852
#    f_ref[0] = [ 0.08021463 -0.12090591  0.20417559] | f_pred[0] = [-0.54490304 58.51145554 84.39749908]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0063.cif | e_ref = -4.278530 | e_pred = -2583.449951 | ΔE = -2579.171422
#    f_ref[0] = [ 0.00530145 -0.19935869  0.17223856] | f_pred[0] = [-0.49711609 67.68839264 85.91464996]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0064.cif | e_ref = -4.278190 | e_pred = -2583.376465 | ΔE = -2579.098275
#    f_ref[0] = [-0.05535442 -0.2756725   0.14626269] | f_pred[0] = [ 3.81593466 69.01732635 80.85433197]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0065.cif | e_ref = -4.277924 | e_pred = -2583.314941 | ΔE = -2579.037018
#    f_ref[0] = [-0.09306304 -0.33676451  0.10097393] | f_pred[0] = [ 9.33003235 73.7845993  85.27433014]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0066.cif | e_ref = -4.277906 | e_pred = -2583.265137 | ΔE = -2578.987230
#    f_ref[0] = [-0.10094999 -0.34035981  0.05888122] | f_pred[0] = [ 6.05044222 73.14642334 82.20185089]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0067.cif | e_ref = -4.278135 | e_pred = -2583.253418 | ΔE = -2578.975283
#    f_ref[0] = [-0.083341   -0.28666285  0.04818495] | f_pred[0] = [ 8.87083626 68.91498566 81.07141113]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0068.cif | e_ref = -4.278454 | e_pred = -2583.268555 | ΔE = -2578.990100
#    f_ref[0] = [-0.04004171 -0.19856435  0.05276831] | f_pred[0] = [12.11312962 56.77934647 79.74410248]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0069.cif | e_ref = -4.278809 | e_pred = -2583.296631 | ΔE = -2579.017822
#    f_ref[0] = [ 0.03434446 -0.07854014  0.06290904] | f_pred[0] = [17.52958488 58.55048752 84.58177185]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0070.cif | e_ref = -4.279070 | e_pred = -2583.324707 | ΔE = -2579.045637
#    f_ref[0] = [0.09782585 0.05898782 0.08211222] | f_pred[0] = [17.86058235 67.78617096 93.27677917]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0071.cif | e_ref = -4.279177 | e_pred = -2583.339600 | ΔE = -2579.060423
#    f_ref[0] = [0.1755386  0.25022048 0.1146609 ] | f_pred[0] = [13.94852638 67.87728882 97.57534027]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0072.cif | e_ref = -4.279123 | e_pred = -2583.346924 | ΔE = -2579.067801
#    f_ref[0] = [0.21596394 0.38063067 0.1195058 ] | f_pred[0] = [ 17.75934982  75.1713562  102.55654907]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0073.cif | e_ref = -4.278996 | e_pred = -2583.348145 | ΔE = -2579.069149
#    f_ref[0] = [0.16653396 0.412671   0.08622168] | f_pred[0] = [ 28.35808182  74.76315308 107.54515076]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0074.cif | e_ref = -4.278869 | e_pred = -2583.360352 | ΔE = -2579.081482
#    f_ref[0] = [0.02337583 0.34661487 0.02398606] | f_pred[0] = [ 37.41225433  68.92232513 109.41832733]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0075.cif | e_ref = -4.278688 | e_pred = -2583.377441 | ΔE = -2579.098753
#    f_ref[0] = [-0.1590821   0.18362561 -0.07896411] | f_pred[0] = [ 45.33276749  69.74537659 111.48365021]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0076.cif | e_ref = -4.278492 | e_pred = -2583.387451 | ΔE = -2579.108959
#    f_ref[0] = [-0.35520265  0.01936706 -0.15666157] | f_pred[0] = [ 44.09039688  65.54798126 113.3103714 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0077.cif | e_ref = -4.278309 | e_pred = -2583.386719 | ΔE = -2579.108409
#    f_ref[0] = [-0.48055562 -0.1157231  -0.2165186 ] | f_pred[0] = [ 30.69482803  63.6199913  104.74816132]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0078.cif | e_ref = -4.278222 | e_pred = -2583.375732 | ΔE = -2579.097510
#    f_ref[0] = [-0.45739618 -0.14425273 -0.23791072] | f_pred[0] = [ 26.18960762  63.63742828 100.05667114]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0079.cif | e_ref = -4.277997 | e_pred = -2583.360107 | ΔE = -2579.082110
#    f_ref[0] = [-0.33095154 -0.09444816 -0.22875756] | f_pred[0] = [ 21.78990364  63.21213913 100.54677582]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0080.cif | e_ref = -4.277713 | e_pred = -2583.364014 | ΔE = -2579.086300
#    f_ref[0] = [-0.15100811 -0.00524257 -0.14929149] | f_pred[0] = [ 13.82763195  71.60424042 102.03399658]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0081.cif | e_ref = -4.277448 | e_pred = -2583.388428 | ΔE = -2579.110980
#    f_ref[0] = [ 0.058449    0.10035378 -0.04204237] | f_pred[0] = [ 9.11278915 72.36547089 99.12037659]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0082.cif | e_ref = -4.277106 | e_pred = -2583.428223 | ΔE = -2579.151116
#    f_ref[0] = [0.29475915 0.19521783 0.07249939] | f_pred[0] = [-10.84854889  68.45394135  91.10449982]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0083.cif | e_ref = -4.276721 | e_pred = -2583.463867 | ΔE = -2579.187146
#    f_ref[0] = [0.51344091 0.23610112 0.16888076] | f_pred[0] = [-2.47005677 71.40331268 95.91056061]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0084.cif | e_ref = -4.276403 | e_pred = -2583.484863 | ΔE = -2579.208460
#    f_ref[0] = [0.59903699 0.19926977 0.16602203] | f_pred[0] = [-1.46711302 64.29655457 94.51373291]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0085.cif | e_ref = -4.276381 | e_pred = -2583.489258 | ΔE = -2579.212876
#    f_ref[0] = [0.43555242 0.01460724 0.01510498] | f_pred[0] = [-19.13822174  46.52913284  79.65432739]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0086.cif | e_ref = -4.276530 | e_pred = -2583.455566 | ΔE = -2579.179037
#    f_ref[0] = [ 0.21136364 -0.19878368 -0.15770081] | f_pred[0] = [-27.12918091  39.24833298  68.26873779]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0087.cif | e_ref = -4.276615 | e_pred = -2583.396240 | ΔE = -2579.119625
#    f_ref[0] = [ 0.04100195 -0.36809915 -0.27361894] | f_pred[0] = [-25.3339138   25.25275421  58.02030182]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0088.cif | e_ref = -4.276383 | e_pred = -2583.333252 | ΔE = -2579.056869
#    f_ref[0] = [-0.07259011 -0.48983172 -0.32643166] | f_pred[0] = [-23.24449348  20.29894829  53.9875946 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0089.cif | e_ref = -4.276125 | e_pred = -2583.277344 | ΔE = -2579.001218
#    f_ref[0] = [-0.14520259 -0.52927196 -0.34875545] | f_pred[0] = [-23.38180351  28.09770203  56.38402176]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0090.cif | e_ref = -4.276186 | e_pred = -2583.222656 | ΔE = -2578.946470
#    f_ref[0] = [-0.17719232 -0.49946156 -0.35027727] | f_pred[0] = [-22.04548836  28.11159897  61.57494736]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0091.cif | e_ref = -4.276565 | e_pred = -2583.177734 | ΔE = -2578.901170
#    f_ref[0] = [-0.15397626 -0.39648312 -0.27819094] | f_pred[0] = [-19.2663269   38.74240875  72.02902222]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0092.cif | e_ref = -4.276971 | e_pred = -2583.140137 | ΔE = -2578.863165
#    f_ref[0] = [-0.06906001 -0.22309822 -0.16614932] | f_pred[0] = [-20.97965813  53.75618744  81.45491791]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0093.cif | e_ref = -4.277244 | e_pred = -2583.101562 | ΔE = -2578.824318
#    f_ref[0] = [ 0.01219138 -0.01980071 -0.02848604] | f_pred[0] = [-22.88783455  60.39860535  79.92689514]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0094.cif | e_ref = -4.277368 | e_pred = -2583.071289 | ΔE = -2578.793921
#    f_ref[0] = [0.09874558 0.15515366 0.10579146] | f_pred[0] = [-26.08704948  61.4220314   82.87746429]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0095.cif | e_ref = -4.277542 | e_pred = -2583.054688 | ΔE = -2578.777146
#    f_ref[0] = [0.16639885 0.31153682 0.24341357] | f_pred[0] = [-24.96748734  69.84391785  89.26944733]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0096.cif | e_ref = -4.277806 | e_pred = -2583.056885 | ΔE = -2578.779079
#    f_ref[0] = [0.21758273 0.41828296 0.35021719] | f_pred[0] = [-14.73143578  81.43093872  97.31621552]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0097.cif | e_ref = -4.277920 | e_pred = -2583.061523 | ΔE = -2578.783603
#    f_ref[0] = [0.19591036 0.42524236 0.40444827] | f_pred[0] = [-16.22535896  85.99984741  98.50152588]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0098.cif | e_ref = -4.277906 | e_pred = -2583.069580 | ΔE = -2578.791674
#    f_ref[0] = [0.08612034 0.35488397 0.38532832] | f_pred[0] = [-19.58742714  77.38031769  96.99098969]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0099.cif | e_ref = -4.277838 | e_pred = -2583.062744 | ΔE = -2578.784906
#    f_ref[0] = [-0.05798408  0.2081013   0.28515399] | f_pred[0] = [-22.5402832   54.81002808  85.75543976]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0100.cif | e_ref = -4.277843 | e_pred = -2583.051758 | ΔE = -2578.773915
#    f_ref[0] = [-0.18302685  0.03299265  0.16076   ] | f_pred[0] = [-3.65059805 53.66476059 90.1532135 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0101.cif | e_ref = -4.278008 | e_pred = -2583.037354 | ΔE = -2578.759346
#    f_ref[0] = [-0.25370625 -0.14954732  0.01089742] | f_pred[0] = [-2.13337016 35.36431122 84.29853058]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0102.cif | e_ref = -4.278126 | e_pred = -2583.012451 | ΔE = -2578.734325
#    f_ref[0] = [-0.23843363 -0.28649282 -0.14516988] | f_pred[0] = [ 3.34500933 35.10705948 80.83591461]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0103.cif | e_ref = -4.278125 | e_pred = -2582.969971 | ΔE = -2578.691845
#    f_ref[0] = [-0.19538945 -0.3824237  -0.27736408] | f_pred[0] = [-7.01713085 33.72489929 78.84580231]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0104.cif | e_ref = -4.277925 | e_pred = -2582.911377 | ΔE = -2578.633451
#    f_ref[0] = [-0.05408566 -0.42858809 -0.3939414 ] | f_pred[0] = [-13.56218147  34.0471611   75.80027008]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0105.cif | e_ref = -4.277656 | e_pred = -2582.833252 | ΔE = -2578.555596
#    f_ref[0] = [ 0.11394806 -0.40851331 -0.41040576] | f_pred[0] = [-21.62280464  35.47071457  70.09053802]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0106.cif | e_ref = -4.277599 | e_pred = -2582.740234 | ΔE = -2578.462636
#    f_ref[0] = [ 0.25142187 -0.33741769 -0.32507521] | f_pred[0] = [-29.69369888  32.37530136  65.32621002]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0107.cif | e_ref = -4.277832 | e_pred = -2582.645508 | ΔE = -2578.367676
#    f_ref[0] = [ 0.33573091 -0.24161683 -0.12709291] | f_pred[0] = [-41.51048279  36.15868378  57.60064316]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0108.cif | e_ref = -4.278206 | e_pred = -2582.564209 | ΔE = -2578.286003
#    f_ref[0] = [ 0.3361263  -0.16668542  0.07521482] | f_pred[0] = [-35.61862564  39.84741974  67.38937378]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0109.cif | e_ref = -4.278409 | e_pred = -2582.499512 | ΔE = -2578.221103
#    f_ref[0] = [ 0.271871   -0.12634028  0.21177383] | f_pred[0] = [-33.66824341  42.73329926  81.98123169]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0110.cif | e_ref = -4.278297 | e_pred = -2582.457275 | ΔE = -2578.178978
#    f_ref[0] = [ 0.15546672 -0.09489037  0.30425236] | f_pred[0] = [-18.77248955  52.58523941  94.32110596]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0111.cif | e_ref = -4.277850 | e_pred = -2582.438965 | ΔE = -2578.161115
#    f_ref[0] = [-0.00534204 -0.0509795   0.34876487] | f_pred[0] = [-9.27628231 54.3126297  97.38500214]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0112.cif | e_ref = -4.277194 | e_pred = -2582.437012 | ΔE = -2578.159817
#    f_ref[0] = [-0.18941073  0.03587519  0.36424616] | f_pred[0] = [-2.4436655  53.70344543 93.5854187 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0113.cif | e_ref = -4.276547 | e_pred = -2582.436523 | ΔE = -2578.159976
#    f_ref[0] = [-0.37842301  0.10488559  0.33794123] | f_pred[0] = [-1.0382942  47.86465073 95.68981171]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0114.cif | e_ref = -4.276305 | e_pred = -2582.434814 | ΔE = -2578.158510
#    f_ref[0] = [-0.48561093  0.19019555  0.30085912] | f_pred[0] = [-3.09773016 45.30414581 91.91412354]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0115.cif | e_ref = -4.276454 | e_pred = -2582.450195 | ΔE = -2578.173741
#    f_ref[0] = [-0.46395093  0.22157651  0.24555469] | f_pred[0] = [10.09558773 51.324646   95.80508423]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0116.cif | e_ref = -4.276741 | e_pred = -2582.481934 | ΔE = -2578.205193
#    f_ref[0] = [-0.35131568  0.21726857  0.14844315] | f_pred[0] = [ 18.94518852  53.43241501 101.57855225]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0117.cif | e_ref = -4.276815 | e_pred = -2582.521240 | ΔE = -2578.244425
#    f_ref[0] = [-0.16246131  0.23569874  0.03050784] | f_pred[0] = [ 16.48398209  56.75654602 104.91599274]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0118.cif | e_ref = -4.276659 | e_pred = -2582.547363 | ΔE = -2578.270705
#    f_ref[0] = [ 0.03316408  0.24116004 -0.09732956] | f_pred[0] = [ 25.8724575   55.03386307 102.70213318]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0119.cif | e_ref = -4.276340 | e_pred = -2582.561279 | ΔE = -2578.284939
#    f_ref[0] = [ 0.1851899   0.21439476 -0.23443991] | f_pred[0] = [26.16046715 41.31683731 99.13787842]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0120.cif | e_ref = -4.276020 | e_pred = -2582.553467 | ΔE = -2578.277447
#    f_ref[0] = [ 0.25257918  0.17491326 -0.33862472] | f_pred[0] = [24.6212883  33.22806549 99.48351288]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0121.cif | e_ref = -4.275962 | e_pred = -2582.528076 | ΔE = -2578.252114
#    f_ref[0] = [ 0.25011256  0.11716793 -0.40330526] | f_pred[0] = [23.63858032 26.55819893 95.51638794]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0122.cif | e_ref = -4.276249 | e_pred = -2582.502686 | ΔE = -2578.226436
#    f_ref[0] = [ 0.19739883  0.03926135 -0.4482694 ] | f_pred[0] = [19.37212181 22.14854431 92.50467682]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0123.cif | e_ref = -4.276734 | e_pred = -2582.483887 | ΔE = -2578.207153
#    f_ref[0] = [ 0.09399322  0.00254909 -0.4047806 ] | f_pred[0] = [25.90378761 14.60590553 90.31112671]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0124.cif | e_ref = -4.277246 | e_pred = -2582.465332 | ΔE = -2578.188086
#    f_ref[0] = [-0.03551862 -0.00370421 -0.30679128] | f_pred[0] = [35.58323669  9.93061447 89.64002991]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0125.cif | e_ref = -4.277740 | e_pred = -2582.464844 | ΔE = -2578.187103
#    f_ref[0] = [-0.12538768 -0.02656994 -0.20461206] | f_pred[0] = [34.77305222 14.66460037 84.47631836]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0126.cif | e_ref = -4.278086 | e_pred = -2582.453857 | ΔE = -2578.175771
#    f_ref[0] = [-0.16946043 -0.02838577 -0.07580426] | f_pred[0] = [30.49965286 17.37225914 86.07006073]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0127.cif | e_ref = -4.278067 | e_pred = -2582.420654 | ΔE = -2578.142587
#    f_ref[0] = [-0.10632415 -0.01573378  0.08916359] | f_pred[0] = [20.97267723 18.97096634 83.90066528]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0128.cif | e_ref = -4.277656 | e_pred = -2582.378174 | ΔE = -2578.100518
#    f_ref[0] = [ 0.0157984  -0.02645202  0.25164551] | f_pred[0] = [16.78918648 25.51079178 83.02518463]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0129.cif | e_ref = -4.277161 | e_pred = -2582.318359 | ΔE = -2578.041199
#    f_ref[0] = [ 0.1185763  -0.07142232  0.36874154] | f_pred[0] = [ 3.74804926 26.30421448 85.11922455]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0130.cif | e_ref = -4.276812 | e_pred = -2582.252930 | ΔE = -2577.976118
#    f_ref[0] = [ 0.13886324 -0.18699147  0.41747552] | f_pred[0] = [-0.79536158 25.86136246 86.50242615]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0131.cif | e_ref = -4.276658 | e_pred = -2582.207520 | ΔE = -2577.930862
#    f_ref[0] = [ 0.09822008 -0.33135721  0.43175423] | f_pred[0] = [-8.60367203 31.35889435 82.89885712]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0132.cif | e_ref = -4.276538 | e_pred = -2582.196289 | ΔE = -2577.919751
#    f_ref[0] = [ 0.00129819 -0.45949107  0.39710972] | f_pred[0] = [-11.13101387  31.39452934  82.53248596]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0133.cif | e_ref = -4.276432 | e_pred = -2582.205566 | ΔE = -2577.929135
#    f_ref[0] = [-0.08269177 -0.50894922  0.30834377] | f_pred[0] = [4.62180972e-02 3.21440430e+01 8.73323898e+01]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0134.cif | e_ref = -4.276338 | e_pred = -2582.225830 | ΔE = -2577.949492
#    f_ref[0] = [-0.13789578 -0.51421863  0.17487396] | f_pred[0] = [ 7.40502357 41.58384323 95.80374908]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0135.cif | e_ref = -4.276393 | e_pred = -2582.248047 | ΔE = -2577.971653
#    f_ref[0] = [-0.11984184 -0.42780492 -0.00424133] | f_pred[0] = [ 8.14184952 51.56597519 95.98825073]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0136.cif | e_ref = -4.276715 | e_pred = -2582.255127 | ΔE = -2577.978412
#    f_ref[0] = [ 0.00356234 -0.22621189 -0.18519531] | f_pred[0] = [11.53218842 60.90942764 97.73275757]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0137.cif | e_ref = -4.277092 | e_pred = -2582.242432 | ΔE = -2577.965340
#    f_ref[0] = [ 0.19677269  0.01859597 -0.34297368] | f_pred[0] = [ 21.74619293  72.96353149 108.31155396]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0138.cif | e_ref = -4.277245 | e_pred = -2582.213135 | ΔE = -2577.935890
#    f_ref[0] = [ 0.35906261  0.28496197 -0.33395249] | f_pred[0] = [ 32.74087906  85.8576355  127.76371765]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0139.cif | e_ref = -4.277116 | e_pred = -2582.173828 | ΔE = -2577.896712
#    f_ref[0] = [ 0.44451171  0.51723236 -0.18628883] | f_pred[0] = [ 55.26279831 105.45169067 157.92520142]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0140.cif | e_ref = -4.276862 | e_pred = -2582.098877 | ΔE = -2577.822015
#    f_ref[0] = [ 0.43451181  0.68089193 -0.00660067] | f_pred[0] = [ 65.4617157  122.69890594 178.78205872]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0141.cif | e_ref = -4.276563 | e_pred = -2582.002441 | ΔE = -2577.725878
#    f_ref[0] = [0.3300527  0.67845505 0.08120364] | f_pred[0] = [ 74.61908722 125.45061493 177.64064026]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0142.cif | e_ref = -4.276267 | e_pred = -2581.909180 | ΔE = -2577.632913
#    f_ref[0] = [0.08150293 0.51694334 0.08872667] | f_pred[0] = [ 74.59322357 113.42782593 168.25964355]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0143.cif | e_ref = -4.275996 | e_pred = -2581.814453 | ΔE = -2577.538457
#    f_ref[0] = [-0.28752223  0.23412307  0.03113195] | f_pred[0] = [ 62.99170303  78.97775269 140.90397644]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0144.cif | e_ref = -4.275889 | e_pred = -2581.706055 | ΔE = -2577.430166
#    f_ref[0] = [-0.66748124 -0.0593527  -0.05277823] | f_pred[0] = [ 46.41085815  68.59883881 114.17411804]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0145.cif | e_ref = -4.275953 | e_pred = -2581.591553 | ΔE = -2577.315599
#    f_ref[0] = [-1.01024914 -0.37111384 -0.12968346] | f_pred[0] = [ 26.30328178  51.53357697 103.96772766]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0146.cif | e_ref = -4.276019 | e_pred = -2581.484375 | ΔE = -2577.208356
#    f_ref[0] = [-1.07141471 -0.53312409 -0.15686899] | f_pred[0] = [ 33.53318787  48.38079834 100.47663116]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0147.cif | e_ref = -4.275814 | e_pred = -2581.376709 | ΔE = -2577.100895
#    f_ref[0] = [-0.71269161 -0.4713729  -0.04262798] | f_pred[0] = [ 27.32152939  48.84334946 102.11676025]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0148.cif | e_ref = -4.275237 | e_pred = -2581.283691 | ΔE = -2577.008455
#    f_ref[0] = [-0.14258626 -0.28144872  0.15297656] | f_pred[0] = [ 2.43669105 48.36298752 92.53573608]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0149.cif | e_ref = -4.274487 | e_pred = -2581.214600 | ΔE = -2576.940112
#    f_ref[0] = [ 0.51870799 -0.06774946  0.41263261] | f_pred[0] = [ 2.57263899 60.39958191 98.3263855 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0150.cif | e_ref = -4.274084 | e_pred = -2581.168457 | ΔE = -2576.894373
#    f_ref[0] = [0.9407745  0.1197241  0.58262438] | f_pred[0] = [ 4.68041039 65.81472778 98.59114838]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0151.cif | e_ref = -4.274253 | e_pred = -2581.132812 | ΔE = -2576.858560
#    f_ref[0] = [0.90090591 0.12085001 0.47963983] | f_pred[0] = [-6.35537004 49.58777618 91.28704834]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0152.cif | e_ref = -4.274698 | e_pred = -2581.092529 | ΔE = -2576.817832
#    f_ref[0] = [0.53540158 0.05007802 0.20612341] | f_pred[0] = [-11.14814758  35.16474915  83.50905609]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0153.cif | e_ref = -4.274983 | e_pred = -2581.077637 | ΔE = -2576.802653
#    f_ref[0] = [ 0.20586042 -0.08574539 -0.08350562] | f_pred[0] = [17.25814438 23.31217003 92.67428589]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0154.cif | e_ref = -4.275047 | e_pred = -2581.084473 | ΔE = -2576.809426
#    f_ref[0] = [-0.0670111  -0.2024406  -0.33151606] | f_pred[0] = [ 5.51623249  4.47451735 85.12561798]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0155.cif | e_ref = -4.274852 | e_pred = -2581.102051 | ΔE = -2576.827199
#    f_ref[0] = [-0.22505684 -0.29236239 -0.56403643] | f_pred[0] = [ 1.05647945  0.76539612 89.25358582]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0156.cif | e_ref = -4.274509 | e_pred = -2581.127930 | ΔE = -2576.853421
#    f_ref[0] = [-0.31059703 -0.328536   -0.70073706] | f_pred[0] = [ 16.38040161   7.6741972  102.47770691]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0157.cif | e_ref = -4.274273 | e_pred = -2581.141846 | ΔE = -2576.867572
#    f_ref[0] = [-0.29436803 -0.28246918 -0.67537016] | f_pred[0] = [ 34.05834579   5.87373161 114.68979645]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0158.cif | e_ref = -4.274253 | e_pred = -2581.146729 | ΔE = -2576.872475
#    f_ref[0] = [-0.19881539 -0.16275868 -0.52544361] | f_pred[0] = [ 33.36735153  14.85213947 123.33927155]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0159.cif | e_ref = -4.274394 | e_pred = -2581.137451 | ΔE = -2576.863058
#    f_ref[0] = [-0.02681058 -0.00064488 -0.27613363] | f_pred[0] = [ 16.90335464  21.00994301 111.87879181]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0160.cif | e_ref = -4.274339 | e_pred = -2581.116699 | ΔE = -2576.842360
#    f_ref[0] = [0.16694424 0.20042102 0.04693522] | f_pred[0] = [ 27.3145752   60.18387985 131.04716492]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0161.cif | e_ref = -4.274101 | e_pred = -2581.100586 | ΔE = -2576.826485
#    f_ref[0] = [0.34324563 0.392768   0.36456063] | f_pred[0] = [ 29.22540855  84.97547913 132.99655151]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0162.cif | e_ref = -4.273930 | e_pred = -2581.098633 | ΔE = -2576.824703
#    f_ref[0] = [0.43147835 0.48523399 0.57573158] | f_pred[0] = [ 30.15722656  98.97694397 136.1887207 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0163.cif | e_ref = -4.273991 | e_pred = -2581.097168 | ΔE = -2576.823177
#    f_ref[0] = [0.45185971 0.4463641  0.66964477] | f_pred[0] = [ 26.84627914  94.84831238 130.24752808]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0164.cif | e_ref = -4.274114 | e_pred = -2581.089111 | ΔE = -2576.814997
#    f_ref[0] = [0.3205744  0.25342825 0.64734375] | f_pred[0] = [ 17.6891613   69.26092529 115.11572266]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0165.cif | e_ref = -4.274049 | e_pred = -2581.083008 | ΔE = -2576.808959
#    f_ref[0] = [0.15681472 0.06267183 0.53639126] | f_pred[0] = [ 15.31620026  51.03519058 105.00708008]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0166.cif | e_ref = -4.273798 | e_pred = -2581.071777 | ΔE = -2576.797979
#    f_ref[0] = [-0.00858342 -0.13968576  0.39115179] | f_pred[0] = [ 1.90051162 28.14751244 89.50317383]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0167.cif | e_ref = -4.273575 | e_pred = -2581.037354 | ΔE = -2576.763779
#    f_ref[0] = [-0.14013229 -0.31740305  0.24182563] | f_pred[0] = [ 3.77977467 13.0096426  84.52571869]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0168.cif | e_ref = -4.273522 | e_pred = -2581.004639 | ΔE = -2576.731117
#    f_ref[0] = [-0.25882909 -0.4351908   0.07674498] | f_pred[0] = [13.53429699 25.28550339 93.63906097]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0169.cif | e_ref = -4.273683 | e_pred = -2580.972412 | ΔE = -2576.698729
#    f_ref[0] = [-0.3010056  -0.49053788 -0.10855132] | f_pred[0] = [14.82313251 20.0275135  87.29282379]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0170.cif | e_ref = -4.273844 | e_pred = -2580.937988 | ΔE = -2576.664145
#    f_ref[0] = [-0.24041474 -0.48060852 -0.24510004] | f_pred[0] = [11.60815811 14.51977158 85.2484436 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0171.cif | e_ref = -4.273883 | e_pred = -2580.894775 | ΔE = -2576.620892
#    f_ref[0] = [-0.11588784 -0.41745451 -0.316452  ] | f_pred[0] = [25.54195023  4.07106018 90.64704132]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0172.cif | e_ref = -4.273929 | e_pred = -2580.840332 | ΔE = -2576.566403
#    f_ref[0] = [ 0.02083001 -0.29131955 -0.33698666] | f_pred[0] = [16.221138    0.93246365 85.96017456]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0173.cif | e_ref = -4.274007 | e_pred = -2580.786865 | ΔE = -2576.512858
#    f_ref[0] = [ 0.14741518 -0.09515463 -0.29317901] | f_pred[0] = [  2.73111248 -15.95757866  77.79969788]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0174.cif | e_ref = -4.274139 | e_pred = -2580.731445 | ΔE = -2576.457306
#    f_ref[0] = [ 0.21278574  0.17461655 -0.19219527] | f_pred[0] = [ 10.5670433   18.47017097 100.39072418]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0175.cif | e_ref = -4.274251 | e_pred = -2580.656982 | ΔE = -2576.382732
#    f_ref[0] = [ 0.18497227  0.4671537  -0.04851932] | f_pred[0] = [ 16.84044075  63.83717346 119.80010986]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0176.cif | e_ref = -4.274116 | e_pred = -2580.568604 | ΔE = -2576.294487
#    f_ref[0] = [0.13195944 0.76473606 0.11996445] | f_pred[0] = [ 35.2350502   96.29109192 139.79328918]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0177.cif | e_ref = -4.273715 | e_pred = -2580.478516 | ΔE = -2576.204800
#    f_ref[0] = [0.07405452 0.87683344 0.20708476] | f_pred[0] = [ 38.01705933  95.3621521  141.74421692]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0178.cif | e_ref = -4.273366 | e_pred = -2580.391846 | ΔE = -2576.118480
#    f_ref[0] = [-0.00410073  0.82710803  0.2436448 ] | f_pred[0] = [ 37.24988174  60.02423096 123.31892395]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0179.cif | e_ref = -4.273281 | e_pred = -2580.316895 | ΔE = -2576.043613
#    f_ref[0] = [-0.14514393  0.63128549  0.23062536] | f_pred[0] = [ 41.69188309  45.56086349 117.06066132]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0180.cif | e_ref = -4.273350 | e_pred = -2580.260742 | ΔE = -2575.987392
#    f_ref[0] = [-0.29404932  0.31284553  0.18554732] | f_pred[0] = [ 39.02168274  30.52859306 113.06626129]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0181.cif | e_ref = -4.273355 | e_pred = -2580.221436 | ΔE = -2575.948081
#    f_ref[0] = [-0.39249682 -0.0416772   0.0749981 ] | f_pred[0] = [25.40471649 26.46926689 97.21615601]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0182.cif | e_ref = -4.273232 | e_pred = -2580.199219 | ΔE = -2575.925986
#    f_ref[0] = [-0.35497335 -0.34868044 -0.04859043] | f_pred[0] = [22.91820908 23.94258118 97.41053009]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0183.cif | e_ref = -4.273091 | e_pred = -2580.180664 | ΔE = -2575.907573
#    f_ref[0] = [-0.20620112 -0.54852659 -0.20343935] | f_pred[0] = [ 19.10184288  29.1486969  101.91926575]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0184.cif | e_ref = -4.272863 | e_pred = -2580.173340 | ΔE = -2575.900477
#    f_ref[0] = [ 0.04937369 -0.68564051 -0.4300403 ] | f_pred[0] = [  7.36077881  31.56760216 106.29130554]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0185.cif | e_ref = -4.272648 | e_pred = -2580.173340 | ΔE = -2575.900692
#    f_ref[0] = [ 0.27334306 -0.70154548 -0.53609079] | f_pred[0] = [  2.5427289   40.5687294  111.71453857]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0186.cif | e_ref = -4.272729 | e_pred = -2580.166992 | ΔE = -2575.894263
#    f_ref[0] = [ 0.41219312 -0.58084673 -0.43851   ] | f_pred[0] = [  9.78341103  44.96160126 106.65176392]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0187.cif | e_ref = -4.273070 | e_pred = -2580.141602 | ΔE = -2575.868532
#    f_ref[0] = [ 0.45831734 -0.31371653 -0.18032512] | f_pred[0] = [14.61658287 51.46392822 95.83291626]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0188.cif | e_ref = -4.273419 | e_pred = -2580.115234 | ΔE = -2575.841815
#    f_ref[0] = [ 0.3957192  -0.11312288  0.04916244] | f_pred[0] = [18.61115456 57.05210876 92.75138092]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0189.cif | e_ref = -4.273583 | e_pred = -2580.093018 | ΔE = -2575.819435
#    f_ref[0] = [0.32770741 0.05773218 0.2214736 ] | f_pred[0] = [22.90633202 62.96744156 96.23574066]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0190.cif | e_ref = -4.273463 | e_pred = -2580.068604 | ΔE = -2575.795140
#    f_ref[0] = [0.11797711 0.18195061 0.30159679] | f_pred[0] = [ 38.13890839  60.89470673 103.22218323]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0191.cif | e_ref = -4.273234 | e_pred = -2580.061279 | ΔE = -2575.788045
#    f_ref[0] = [0.00106027 0.28016543 0.32653952] | f_pred[0] = [ 55.68874359  45.94346237 113.93101501]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0192.cif | e_ref = -4.273175 | e_pred = -2580.062988 | ΔE = -2575.789813
#    f_ref[0] = [-0.10846284  0.26064569  0.30867472] | f_pred[0] = [ 50.13959885  31.55192184 109.05220795]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0193.cif | e_ref = -4.273143 | e_pred = -2580.040039 | ΔE = -2575.766896
#    f_ref[0] = [-0.17629907  0.19388023  0.26162061] | f_pred[0] = [ 40.70019531  33.35836029 102.4217453 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0194.cif | e_ref = -4.272881 | e_pred = -2580.013428 | ΔE = -2575.740547
#    f_ref[0] = [-0.27456507  0.08418447  0.1908109 ] | f_pred[0] = [ 40.86177063  41.80583954 104.21895599]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0195.cif | e_ref = -4.272431 | e_pred = -2579.996826 | ΔE = -2575.724395
#    f_ref[0] = [-0.41888949 -0.03515798  0.07493516] | f_pred[0] = [ 49.38715744  46.36398315 105.2678299 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0196.cif | e_ref = -4.272202 | e_pred = -2579.981445 | ΔE = -2575.709243
#    f_ref[0] = [-0.43591997 -0.09973195 -0.01071225] | f_pred[0] = [ 63.50418091  49.50881958 112.9466629 ]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0197.cif | e_ref = -4.272473 | e_pred = -2579.970215 | ΔE = -2575.697742
#    f_ref[0] = [-0.2815848  -0.03669987 -0.08409259] | f_pred[0] = [ 66.03858185  41.80774689 116.21052551]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0198.cif | e_ref = -4.272875 | e_pred = -2579.946289 | ΔE = -2575.673414
#    f_ref[0] = [-0.02044162  0.10477085 -0.16587542] | f_pred[0] = [ 63.54039383  47.6430397  122.02809906]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0199.cif | e_ref = -4.272894 | e_pred = -2579.917725 | ΔE = -2575.644830
#    f_ref[0] = [ 0.15473555  0.23390245 -0.23396878] | f_pred[0] = [ 62.56092834  59.77531052 127.89572906]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T300_0200.cif | e_ref = -4.272558 | e_pred = -2579.891357 | ΔE = -2575.618799
#    f_ref[0] = [ 0.29162148  0.31194195 -0.22147211] | f_pred[0] = [ 60.73907852  75.84017944 131.17774963]
# cellrelaxed_LLZO_001_Zr_code93_sto__Li_100_slab_heavy_T450_0000.cif | e_ref = -4.302461 | e_pred = -2584.396729 | ΔE = -2580.094268
#    f_ref[0] = [ 0.00165575  0.0065984  -0.00422474] | f_pred[0] = [15.70402336 60.51900864 90.02856445]
# ...
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0122_strain-3_perturbed.cif | e_ref = -3.463268 | e_pred = -2930.020752 | ΔE = -2926.557484
#    f_ref[0] = [-0.00826651  0.15329969  0.16845074] | f_pred[0] = [ 15.95750427 -76.2895813   83.54463196]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0152_strain+2_perturbed.cif | e_ref = -3.484327 | e_pred = -2910.114502 | ΔE = -2906.630175
#    f_ref[0] = [-0.01235483  0.25067049  0.1036553 ] | f_pred[0] = [ 11.25690079 -53.27445984  66.8054657 ]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0152_strain+3_perturbed.cif | e_ref = -3.477861 | e_pred = -2907.005371 | ΔE = -2903.527510
#    f_ref[0] = [0.00526482 0.28783461 0.16307464] | f_pred[0] = [  3.45777917 -52.97561646  64.06504822]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0152_strain-2_perturbed.cif | e_ref = -3.478150 | e_pred = -2923.205078 | ΔE = -2919.726928
#    f_ref[0] = [-0.15308669  0.1092625  -0.19759205] | f_pred[0] = [ 38.58764267 -56.11772537  61.05400085]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0152_strain-3_perturbed.cif | e_ref = -3.467185 | e_pred = -2926.977051 | ΔE = -2923.509866
#    f_ref[0] = [-0.19873121  0.05952385 -0.31444311] | f_pred[0] = [ 41.76302719 -60.27890015  58.91540527]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0167_strain+2_perturbed.cif | e_ref = -3.485151 | e_pred = -2908.847656 | ΔE = -2905.362506
#    f_ref[0] = [0.09464275 0.20665658 0.75231016] | f_pred[0] = [ 58.578228   -96.20874023  49.45615387]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0167_strain+3_perturbed.cif | e_ref = -3.477896 | e_pred = -2905.717529 | ΔE = -2902.239633
#    f_ref[0] = [0.07346392 0.22165929 0.84842312] | f_pred[0] = [  67.87721252 -103.36209106   38.35661697]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0167_strain-2_perturbed.cif | e_ref = -3.482336 | e_pred = -2921.911621 | ΔE = -2918.429285
#    f_ref[0] = [0.14247394 0.11536746 0.28555119] | f_pred[0] = [ 32.1405983  -76.32998657  40.03672791]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0167_strain-3_perturbed.cif | e_ref = -3.472485 | e_pred = -2925.630859 | ΔE = -2922.158374
#    f_ref[0] = [0.15774505 0.07817907 0.15417971] | f_pred[0] = [ 23.82198524 -67.8175354   47.01829529]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0177_strain+2_perturbed.cif | e_ref = -3.479777 | e_pred = -2907.916016 | ΔE = -2904.436239
#    f_ref[0] = [0.22044604 0.23393823 0.76174694] | f_pred[0] = [ 43.95096588 -89.8443222   33.30773163]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0177_strain+3_perturbed.cif | e_ref = -3.471961 | e_pred = -2904.728516 | ΔE = -2901.256555
#    f_ref[0] = [0.24332936 0.25209674 0.84973025] | f_pred[0] = [ 40.37308502 -91.90111542  33.94078827]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0177_strain-2_perturbed.cif | e_ref = -3.478343 | e_pred = -2920.930176 | ΔE = -2917.451833
#    f_ref[0] = [0.09337284 0.14072499 0.48059949] | f_pred[0] = [ 19.21354675 -74.65267181  31.90022469]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0177_strain-3_perturbed.cif | e_ref = -3.468715 | e_pred = -2924.573730 | ΔE = -2921.105015
#    f_ref[0] = [0.08926728 0.14011826 0.41562814] | f_pred[0] = [ 11.64422131 -79.58407593  21.77900124]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0195_strain+2_perturbed.cif | e_ref = -3.480372 | e_pred = -2906.695312 | ΔE = -2903.214941
#    f_ref[0] = [-0.15361737  0.18186912  0.6247077 ] | f_pred[0] = [ 23.25336075 -77.32096863 -42.72590256]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0195_strain+3_perturbed.cif | e_ref = -3.471982 | e_pred = -2903.455566 | ΔE = -2899.983584
#    f_ref[0] = [-0.1150873   0.21247135  0.68211877] | f_pred[0] = [ 20.44186211 -72.59093475 -32.24447632]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0195_strain-2_perturbed.cif | e_ref = -3.481735 | e_pred = -2919.818115 | ΔE = -2916.336380
#    f_ref[0] = [-0.34896603  0.03792691  0.31135756] | f_pred[0] = [ 49.54716492 -73.58112335 -17.19598961]
# cellrelaxed_LLZO_010_O_order5_off__Li_110_slab_heavy_T450_0195_strain-3_perturbed.cif | e_ref = -3.472874 | e_pred = -2923.416992 | ΔE = -2919.944118
#    f_ref[0] = [-4.29165602e-01  2.30321661e-04  2.35031918e-01] | f_pred[0] = [ 47.40190887 -73.99273682 -12.76388168]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain+2_perturbed.cif | e_ref = -3.884334 | e_pred = -2752.430420 | ΔE = -2748.546086
#    f_ref[0] = [-0.01626578  0.0470604   0.38371184] | f_pred[0] = [-97.85433197  38.61394501  54.82842636]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain+3_perturbed.cif | e_ref = -3.881875 | e_pred = -2749.474365 | ΔE = -2745.592491
#    f_ref[0] = [-0.02530874  0.03357144  0.47686374] | f_pred[0] = [-111.723526     40.08863068   50.50188446]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain-2_perturbed.cif | e_ref = -3.859032 | e_pred = -2762.310791 | ΔE = -2758.451759
#    f_ref[0] = [-0.25347057 -0.11606358 -0.02285112] | f_pred[0] = [-34.29955673  39.56261826  77.56771088]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0001_strain-3_perturbed.cif | e_ref = -3.842663 | e_pred = -2764.142334 | ΔE = -2760.299671
#    f_ref[0] = [-0.2905784  -0.18508668 -0.11689028] | f_pred[0] = [-13.50931358  48.16731262  84.98052216]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0093_strain+2_perturbed.cif | e_ref = -3.893992 | e_pred = -2744.289795 | ΔE = -2740.395803
#    f_ref[0] = [0.1117703  0.04909834 0.13302538] | f_pred[0] = [-73.6320343   56.17820358  60.79367447]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0093_strain+3_perturbed.cif | e_ref = -3.890910 | e_pred = -2740.783203 | ΔE = -2736.892293
#    f_ref[0] = [0.10982375 0.10379007 0.20146951] | f_pred[0] = [-71.19885254  60.06451416  70.71541595]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0093_strain-2_perturbed.cif | e_ref = -3.868452 | e_pred = -2759.312500 | ΔE = -2755.444048
#    f_ref[0] = [ 0.03501758 -0.22300351 -0.26920712] | f_pred[0] = [-37.87012863  54.63525772  71.00006104]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0093_strain-3_perturbed.cif | e_ref = -3.851073 | e_pred = -2763.076172 | ΔE = -2759.225099
#    f_ref[0] = [-0.00191024 -0.23308511 -0.32322168] | f_pred[0] = [-24.07469177  50.31856155  75.63259888]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain+2_perturbed.cif | e_ref = -3.900111 | e_pred = -2740.273193 | ΔE = -2736.373082
#    f_ref[0] = [ 0.26561624 -0.30927944 -0.28784364] | f_pred[0] = [-46.28625488  30.34820557  52.96093369]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain+3_perturbed.cif | e_ref = -3.895662 | e_pred = -2736.976318 | ΔE = -2733.080657
#    f_ref[0] = [ 0.25842753 -0.23282899 -0.19246662] | f_pred[0] = [-46.24204254  20.3893261   44.29905701]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain-2_perturbed.cif | e_ref = -3.880717 | e_pred = -2754.862061 | ΔE = -2750.981343
#    f_ref[0] = [ 0.23230828 -0.67560309 -0.85658962] | f_pred[0] = [-13.67513275  78.89850616  73.59656525]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0119_strain-3_perturbed.cif | e_ref = -3.865160 | e_pred = -2758.778564 | ΔE = -2754.913405
#    f_ref[0] = [ 0.21806952 -0.85296935 -0.99894178] | f_pred[0] = [-0.84470725 98.63670349 71.52130127]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain+2_perturbed.cif | e_ref = -3.909254 | e_pred = -2731.053467 | ΔE = -2727.144213
#    f_ref[0] = [ 0.06358994 -0.29262188 -0.07864895] | f_pred[0] = [-68.56475067  53.18212128 -15.76004791]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain+3_perturbed.cif | e_ref = -3.900782 | e_pred = -2728.109375 | ΔE = -2724.208593
#    f_ref[0] = [ 0.12367779 -0.19359525  0.0364897 ] | f_pred[0] = [-65.84156799  33.51925278  -3.43060398]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain-2_perturbed.cif | e_ref = -3.905504 | e_pred = -2744.113037 | ΔE = -2740.207533
#    f_ref[0] = [-0.06807129 -0.47543681 -0.50789833] | f_pred[0] = [-12.68336678  63.72842407 -28.99951553]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0186_strain-3_perturbed.cif | e_ref = -3.894106 | e_pred = -2747.904297 | ΔE = -2744.010191
#    f_ref[0] = [-0.10902543 -0.54455787 -0.65483147] | f_pred[0] = [  0.26031494  44.84667206 -56.84154892]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain+2_perturbed.cif | e_ref = -3.910567 | e_pred = -2730.559326 | ΔE = -2726.648759
#    f_ref[0] = [0.23527867 0.19329177 0.31257188] | f_pred[0] = [-12.93023682  49.71253586 -54.236866  ]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain+3_perturbed.cif | e_ref = -3.901469 | e_pred = -2727.652344 | ΔE = -2723.750875
#    f_ref[0] = [0.24737674 0.23972762 0.40234208] | f_pred[0] = [-19.47430038  38.24016953 -57.56060028]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain-2_perturbed.cif | e_ref = -3.909622 | e_pred = -2743.343994 | ΔE = -2739.434372
#    f_ref[0] = [ 0.15170909  0.0691573  -0.0127752 ] | f_pred[0] = [ -8.07033157  52.93862152 -57.33450317]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T300_0195_strain-3_perturbed.cif | e_ref = -3.898882 | e_pred = -2747.061279 | ΔE = -2743.162397
#    f_ref[0] = [ 0.12958135 -0.0188549  -0.11188715] | f_pred[0] = [  0.70440865  50.68307877 -53.83592224]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain+2_perturbed.cif | e_ref = -3.873506 | e_pred = -2752.513428 | ΔE = -2748.639922
#    f_ref[0] = [ 0.11231013 -0.03898282  0.26819262] | f_pred[0] = [-56.77006531  18.14164352  58.40733337]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain+3_perturbed.cif | e_ref = -3.871295 | e_pred = -2749.557861 | ΔE = -2745.686566
#    f_ref[0] = [ 0.14411886 -0.01451932  0.36492139] | f_pred[0] = [-79.6207962   22.15589142  65.44764709]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain-2_perturbed.cif | e_ref = -3.846251 | e_pred = -2762.309570 | ΔE = -2758.463320
#    f_ref[0] = [-0.08979718 -0.15716848 -0.20298705] | f_pred[0] = [-17.59263229  36.72017288  77.75036621]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0002_strain-3_perturbed.cif | e_ref = -3.829128 | e_pred = -2764.134033 | ΔE = -2760.304905
#    f_ref[0] = [-0.07208373 -0.16285801 -0.31489649] | f_pred[0] = [-4.72349167 41.43801498 93.42765045]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain+2_perturbed.cif | e_ref = -3.869579 | e_pred = -2749.033691 | ΔE = -2745.164113
#    f_ref[0] = [-0.27692127 -0.3721182  -0.11710911] | f_pred[0] = [-35.47011185  43.28025818  90.07801056]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain+3_perturbed.cif | e_ref = -3.867280 | e_pred = -2745.576172 | ΔE = -2741.708892
#    f_ref[0] = [-0.27386582 -0.26978421 -0.02436443] | f_pred[0] = [-36.49279404  40.15267563  82.02928925]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain-2_perturbed.cif | e_ref = -3.841997 | e_pred = -2762.325684 | ΔE = -2758.483687
#    f_ref[0] = [-0.38328129 -0.65214479 -0.46423781] | f_pred[0] = [-29.10408783  24.3373661   59.99128723]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0065_strain-3_perturbed.cif | e_ref = -3.824993 | e_pred = -2765.326904 | ΔE = -2761.501911
#    f_ref[0] = [-0.45284784 -0.77421498 -0.58372217] | f_pred[0] = [-26.28348732  50.52747345  70.84822083]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain+2_perturbed.cif | e_ref = -3.871526 | e_pred = -2748.022217 | ΔE = -2744.150691
#    f_ref[0] = [0.18711936 0.35019422 0.28272226] | f_pred[0] = [-62.94913864  71.79312134  85.03114319]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain+3_perturbed.cif | e_ref = -3.869371 | e_pred = -2744.582275 | ΔE = -2740.712904
#    f_ref[0] = [0.24448931 0.36205679 0.37713653] | f_pred[0] = [-59.26424789  71.51880646  98.71946716]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain-2_perturbed.cif | e_ref = -3.842685 | e_pred = -2761.705811 | ΔE = -2757.863126
#    f_ref[0] = [ 0.09357584  0.38157153 -0.09238423] | f_pred[0] = [-29.63281631  50.81007767 105.37709808]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0075_strain-3_perturbed.cif | e_ref = -3.824880 | e_pred = -2764.905518 | ΔE = -2761.080637
#    f_ref[0] = [ 0.05053947  0.38200778 -0.20342112] | f_pred[0] = [-13.95287323  57.36073303 120.46353149]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain+2_perturbed.cif | e_ref = -3.888087 | e_pred = -2738.928467 | ΔE = -2735.040380
#    f_ref[0] = [ 0.18442747 -0.02680132  0.33221915] | f_pred[0] = [-13.62586117   4.8056078   76.98965454]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain+3_perturbed.cif | e_ref = -3.883826 | e_pred = -2735.535645 | ΔE = -2731.651819
#    f_ref[0] = [0.28392941 0.0056284  0.41477337] | f_pred[0] = [-21.95263672  -3.00217676  63.63580322]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain-2_perturbed.cif | e_ref = -3.867449 | e_pred = -2753.592285 | ΔE = -2749.724836
#    f_ref[0] = [-0.21733989 -0.08839911 -0.0204733 ] | f_pred[0] = [-4.96489239 42.5873642  93.70966339]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0132_strain-3_perturbed.cif | e_ref = -3.851186 | e_pred = -2757.464844 | ΔE = -2753.613658
#    f_ref[0] = [-0.28050485 -0.05753843 -0.14874595] | f_pred[0] = [-4.98621845 48.26143646 92.44442749]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain+2_perturbed.cif | e_ref = -3.891395 | e_pred = -2735.310547 | ΔE = -2731.419152
#    f_ref[0] = [0.04082134 0.32494378 0.12850736] | f_pred[0] = [-68.07056427  40.0534668   81.15950012]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain+3_perturbed.cif | e_ref = -3.885761 | e_pred = -2732.036377 | ΔE = -2728.150616
#    f_ref[0] = [0.08631686 0.35819697 0.1920214 ] | f_pred[0] = [-85.73258972  43.65304184  79.86473083]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain-2_perturbed.cif | e_ref = -3.877062 | e_pred = -2749.667480 | ΔE = -2745.790418
#    f_ref[0] = [-0.16535109  0.12769921 -0.2976957 ] | f_pred[0] = [  7.88061142  51.20903778 101.05191803]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0160_strain-3_perturbed.cif | e_ref = -3.862217 | e_pred = -2753.639160 | ΔE = -2749.776943
#    f_ref[0] = [-0.185073    0.10253093 -0.44432983] | f_pred[0] = [29.42149162 35.36555099 96.79614258]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain+2_perturbed.cif | e_ref = -3.894942 | e_pred = -2732.530029 | ΔE = -2728.635087
#    f_ref[0] = [-0.1457179   0.11800732 -0.13632363] | f_pred[0] = [-64.15540314  76.34683228  77.35190582]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain+3_perturbed.cif | e_ref = -3.887790 | e_pred = -2729.416992 | ΔE = -2725.529202
#    f_ref[0] = [-0.08107433  0.13972686 -0.0263182 ] | f_pred[0] = [-60.06010437  76.56686401  84.37156677]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain-2_perturbed.cif | e_ref = -3.885207 | e_pred = -2746.357910 | ΔE = -2742.472703
#    f_ref[0] = [-0.28566483  0.09462141 -0.50321794] | f_pred[0] = [-52.39953232  68.4467392   43.65303802]
# cellrelaxed_LLZO_011_La_code71_sto__Li_100_slab_heavy_T450_0181_strain-3_perturbed.cif | e_ref = -3.871969 | e_pred = -2750.307129 | ΔE = -2746.435160
#    f_ref[0] = [-0.36960652  0.10781626 -0.68456459] | f_pred[0] = [-35.96770096  54.3291893   24.75530815]
#
# ✅ Saved JSON: chgnetT2_vs_universal_comparison.json
# 📊 Saved Excel: chgnetT2_vs_universal_comparison.xlsx
#
# 📊 Global Stats (eV, eV/Å):
# Energy MAE (per atom): 2806.02875 eV
# Energy RMSE (per atom): 2812.20809 eV
# Force MAE: 12.80407 eV/Å
# Force RMSE: 21.83491 eV/Å
# Max Force Abs Error: 1645.23515 eV/Å

# %%
from chgnet.model.model import CHGNet

model = CHGNet.from_file("/home/phanim/harshitrawat/summer/07-29-2025/bestE_epoch8_e115842_f13049_sNA_mNA.pth.tar")
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
